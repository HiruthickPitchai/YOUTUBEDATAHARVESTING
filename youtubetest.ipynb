# %%
from googleapiclient.discovery import build  
import pymongo
import psycopg2
import pandas as pd 
import streamlit as st

# %%
#api key connection

def Api_connect(): #fun
    Api_Id = "AIzaSyB7zVH9QyXu4F_R0thsikNZgdwaZxUtqEY" #apikey

    api_service_name="youtube"
    api_version="v3"
    
    youtube = build(api_service_name,api_version,developerKey=Api_Id) #var=value

    return youtube #funreturn

youtube=Api_connect() #fun call & strore val

# %%
#get channel information

def get_Channel_info(channel_id):
    request = youtube.channels().list(
        part="snippet,ContentDetails,Statistics",
        id=channel_id
    )
    response1 = request.execute()

    for i in range(0, len(response1["items"])):
        data = dict(
                    Channel_Name=response1["items"][i]["snippet"]["title"],
                    Channel_Id=response1["items"][i]["id"],
                    Subscription_Count=response1["items"][i]["statistics"]["subscriberCount"],
                    Views=response1["items"][i]["statistics"]["viewCount"],
                    Total_Videos=response1["items"][i]["statistics"]["videoCount"],
                    Channel_Description=response1["items"][i]["snippet"]["description"],
                    Playlist_Id=response1["items"][i]["contentDetails"]["relatedPlaylists"]["uploads"])

    return data

# %%
#error makes clever academy  :    UCwr-evhuzGZgDFrq_1pLt_A
#hrnavin  : UC-O3_F-UpwzKvSkvO0DW9qg
#a2d     :  UCvyZS6W6zMJCZBVzF-Ei6sw
#sunnews : UCYlh4lH762HvHt6mmiecyWQ

# %%
channel_details=get_Channel_info("UCwr-evhuzGZgDFrq_1pLt_A")

# %%
channel_details
# Out:
# {'Channel_Name': 'Error Makes Clever Academy',
#  'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#  'Subscription_Count': '554000',
#  'Views': '30820594',
#  'Total_Videos': '130',
#  'Channel_Description': 'Empowering developers to level up their skills through training in software development technologies🧑\u200d💻\nJoin our community today !\n',
#  'Playlist_Id': 'UUwr-evhuzGZgDFrq_1pLt_A'}

# %%
#get playlist ids


def get_playlist_info(channel_id):
    request = youtube.playlists().list(
    part="snippet,contentDetails",
    channelId=channel_id,
    maxResults=50
    )
    response = request.execute()
    All_data=[]
    for item in response['items']: 
        data={'PlaylistId':item['id'],
                'Title':item['snippet']['title'],
                'ChannelId':item['snippet']['channelId'],
                'ChannelName':item['snippet']['channelTitle'],
                'PublishedAt':item['snippet']['publishedAt'],
                'VideoCount':item['contentDetails']['itemCount']
                }
        All_data.append(data)
    All_data = []
    next_page_token = None
    next_page = True
    while next_page:

        request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token
            )
        response = request.execute()

        for item in response['items']: 
            data={'PlaylistId':item['id'],
                    'Title':item['snippet']['title'],
                    'ChannelId':item['snippet']['channelId'],
                    'ChannelName':item['snippet']['channelTitle'],
                    'PublishedAt':item['snippet']['publishedAt'],
                    'VideoCount':item['contentDetails']['itemCount']}
            All_data.append(data)
        next_page_token = response.get('nextPageToken')

        while next_page_token is not None:

            request = youtube.playlists().list(
                part="snippet,contentDetails",
                channelId=channel_id,
                maxResults=50
                )
            response = request.execute()

            for item in response['items']: 
                data={'PlaylistId':item['id'],
                      'Title':item['snippet']['title'],
                      'ChannelId':item['snippet']['channelId'],
                      'ChannelName':item['snippet']['channelTitle'],
                      'PublishedAt':item['snippet']['publishedAt'],
                      'VideoCount':item['contentDetails']['itemCount']}
                All_data.append(data)
            next_page_token = response.get('nextPageToken')
            if  next_page_token is None:
                break
        if next_page_token is None:
            next_page=False
    return All_data

# %%
#get video ids

def get_videos_ids(channel_id):
    video_ids = []
    # get Uploads playlist id
    response = youtube.channels().list(id=channel_id, 
                                  part='contentDetails').execute()
    playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    next_page_token = None
    
    while True:
        response1 = youtube.playlistItems().list( 
                                           part = 'snippet',
                                           playlistId = playlist_id, 
                                           maxResults = 50,
                                           pageToken = next_page_token).execute()
        
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token = response1.get('nextPageToken')
        
        if next_page_token is None:
            break
    return video_ids

# %%
Video_Ids=get_videos_ids('UCwr-evhuzGZgDFrq_1pLt_A')

# %%
Video_Ids
# Out:
# ['YJsqKbqgpEY',
#  'x3dQsMkJgDg',
#  'QaoKoeMYvoY',
#  'jnfyH1k2c38',
#  'cfCe3wNXtlE',
#  'L-PxA7xa6UA',
#  'J16CecpALAk',
#  '7dSJubxFWv0',
#  'djbJjGp2tc8',
#  '1h35ad0yn-w',
#  '_pqX3eIOQ9k',
#  'kkn0pnLqaco',
#  'hVWhsHOQbXM',
#  'qbl7tOaQF20',
#  'JHHBOLBt1JI',
#  '6ImT0CuJVX4',
#  '1Z4itB15U_s',
#  'iBEAquFXHWg',
#  '9SwNLkRmg7Y',
#  '9cQaOXgi8XQ',
#  'ytQQ1TXz-CI',
#  't22s6omEr4M',
#  'FZmR_m0KuC8',
#  'Xd0uGWDrVXI',
#  'CsnEBjbdO7g',
#  'sJSucvrMp80',
#  'gUMbjfuudZ0',
#  'xZZrnDtK0qc',
#  '6RmVZ4yRKeE',
#  'Omu2WhkoydU',
#  'eIwJZBzT7fg',
#  'poo0BXryffI',
#  'sSKFx39UUpk',
#  'l4y5flTC1g4',
#  'GnOSxrLh3_0',
#  'tcjcjHX9wcA',
#  'e_su8zuTtMo',
#  '5682golSP5I',
#  'Y7Kqbc0sDGI',
#  '4igiQuJaifU',
#  't8VY9kaM_t0',
#  '-FfEiNu2ar8',
#  'uhWu8JBRIa0',
#  '_m7ap8EvAEM',
#  'xPhImdnkJyo',
#  'zHjpQnmA9sg',
#  'gsvYvufx1e0',
#  'y31EUnxHLJE',
#  '53eqvG3-1AM',
#  'QvTo1_-n0UE',
#  'vfs1wBDoqBY',
#  'QzXMQM16zjY',
#  'jgboA8ifFM0',
#  '3FiFcG8XKrU',
#  'InymDJy3QxA',
#  'Od0iQRhq4HA',
#  'HN_eKSceHmE',
#  'pH2BmRwn-SQ',
#  'FYErehuSuuw',
#  'NMuaxhPbP6Y',
#  'JzKKtOH6QII',
#  'Bj924hFoCQk',
#  'FXUt1p4LH2Q',
#  'VIBWdLLq9kQ',
#  '4E8IwucpbfQ',
#  '_ZwG1c-gLXM',
#  'L-EFQ5q6RvM',
#  't9iC51H4-fY',
#  'eSymSLKy2QE',
#  'jvMthS479GA',
#  'asOAW9tLwZ4',
#  '77j1NgGFBCc',
#  'zKlmRd7aB7U',
#  'm67-bOpOoPU',
#  'Ll62YIkEvs8',
#  'ufRLns-QQh0',
#  'tOqypPfFMtg',
#  'yOpZ5dz8yng',
#  'm2xIFRXHnJY',
#  'lkxWGf1l1x4',
#  'Z09I_OHuflw',
#  'EXK7ukaSLlk',
#  '1LAYd0xtkkI',
#  'OFjHWCdCCcs',
#  'CxLFjJHkWLI',
#  'HuSZC3JDKrM',
#  'tEzYlonaKYs',
#  'oVypM2Ld1PA',
#  '5AKE_lm_XTI',
#  'O8VANFJI2V4',
#  'u2xA51-7WHE',
#  'PJxwAJdWpVY',
#  '2h4qCm7Vu64',
#  'K3HD0gJXJYQ',
#  'rltSHY2Y7-c',
#  'XCDDWb71Zr8',
#  'Gb1oZy6kAWA',
#  'jmXDnRHR4cw',
#  'hvmduOeCh4o',
#  'Np3fzqoaYQw',
#  'wuKfqoPsf7E',
#  'ChMbB1TC0BE',
#  '7gEzEAIELgQ',
#  'WMh9yACCYwI',
#  'fKn48BMN_p0',
#  'zwM_9R37pyo',
#  'cJ9ojrWq2e4',
#  'hqD4pfTPAMk',
#  'KYmMV9tABjU',
#  'gh3JS0wgSb0',
#  'TQTnqQ6CypM',
#  'IThpx7Izn-4',
#  'eYtf9a8LoIg',
#  'rqkkd-h087A',
#  'Rtmgt2Qfqr4',
#  'BVIoAILnZ4Q',
#  'Y0RoLM48xP4',
#  't_WIjhkZNoA',
#  'jk7q7QTFnvI',
#  '5QzzeYHApV0',
#  '2baFLrjuW8s',
#  '50F2ysbYLfI',
#  'ZpyJe4_xVVA',
#  '7tTB8IaHASc',
#  'ONDDWzXHW28',
#  'oBBW3fnGejc',
#  'Krzg0YlFHMs',
#  'tP8Ku1cjRp4',
#  'Q_mugOseqCc',
#  'oubMNuKC8KA']

# %%
len(Video_Ids)
# Out:
# 130

# %%
#get video information

def get_video_info(video_ids):
    video_data = []
    for video_id in video_ids:
        request = youtube.videos().list(
                    part="snippet,contentDetails,statistics",
                    id= video_id)
        response = request.execute()
        for item in response["items"]:
            data = dict(Channel_Name = item['snippet']['channelTitle'],
                        Channel_Id = item['snippet']['channelId'],
                        Video_Id = item['id'],
                        Title = item['snippet']['title'],
                        Tags = item['snippet'].get('tags'),
                        Thumbnail = item['snippet']['thumbnails']['default']['url'],
                        Description = item['snippet']['description'],
                        Published_Date = item['snippet']['publishedAt'],
                        Duration = item['contentDetails']['duration'],
                        Views = item['statistics']['viewCount'],
                        Likes = item['statistics'].get('likeCount'),
                        Comments = item['snippet'].get('commentCount'),
                        Favorite_Count = item['statistics']['favoriteCount'],
                        Definition = item['contentDetails']['definition'],
                        Caption_Status = item['contentDetails']['caption']
                        )
            video_data.append(data)
    return video_data

# %%
video_data=get_video_info(Video_Ids)

# %%
for i in video_data:
    print(i)
# Out:
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'YJsqKbqgpEY', 'Title': 'CSS Media Queries Explained in Tamil | Responsive Web Development Tutorial', 'Tags': ['css', 'media', 'queries', 'webdevelopment', 'tamil', 'emc', 'errormakesclever'], 'Thumbnail': 'https://i.ytimg.com/vi/YJsqKbqgpEY/default.jpg', 'Description': 'Explore the world of CSS Media Queries in Tamil! 💻💡 Learn how to create dynamic web layouts and understand the nuances of web development in Tamil. This tutorial is your gateway to mastering web design concepts in the Tamil language. 🎥🔥 #CSS #MediaQueries #ResponsiveDesign #WebDevelopmentTutorial #TamilTutorial #emc #errormakesclever\n\nErrorMakesClever Instagram Link 👇👇👇\n https://www.instagram.com/errormakesclever\n\nErrorMakesClever Youtube Link 👇👇👇\nhttps://www.youtube.com/@ErrorMakesClever\n\nErrorMakesClever Whatsapp Channel Link 👇👇👇\nhttps://www.whatsapp.com/channel/0029VaARpx2F1YlQunv38L1Z', 'Published_Date': '2024-01-11T12:30:18Z', 'Duration': 'PT24M26S', 'Views': '12530', 'Likes': '520', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'x3dQsMkJgDg', 'Title': 'what is UI vs UX design | Explained for beginners | Roadmap and Resources in Tamil', 'Tags': ['ui', 'ux', 'basics', 'explained', 'tamil', 'emc', 'errormakesclever'], 'Thumbnail': 'https://i.ytimg.com/vi/x3dQsMkJgDg/default.jpg', 'Description': '🌐 Explore the basics of UI/UX design in our latest video, all explained in Tamil! Understand the foundations of UI/UX effortlessly with engaging narratives.\n\n⏰ Time Stamps:\n00:00 Introduction\n00:18 What is UI/UX?\n01:45 Freshers Salary\n02:24 UI/UX Tools\n04:16 Figma AI\n04:45 UI/UX Resources\n05:03 UI/UX Portfolio\n\nDiscover how user interface and user experience collaborate to shape seamless digital experiences! 🎨🚀 #UIDesign #UXExplained #DigitalExperience #TamilTutorial #emc #errormakesclever\n\nErrorMakesClever Instagram Link 👇👇👇\n https://www.instagram.com/errormakesclever\n\nErrorMakesClever Youtube Link 👇👇👇\nhttps://www.youtube.com/@ErrorMakesClever\n\nErrorMakesClever Whatsapp Channel Link 👇👇👇\nhttps://www.whatsapp.com/channel/0029VaARpx2F1YlQunv38L1Z', 'Published_Date': '2024-01-09T12:30:39Z', 'Duration': 'PT6M40S', 'Views': '38470', 'Likes': '2798', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'QaoKoeMYvoY', 'Title': '🔍 LinkedIn Job Search Hack: Pro Tips for Landing Your Dream Job!💼 #shorts #linkedin #jobsearch #emc', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/QaoKoeMYvoY/default.jpg', 'Description': 'Use this Quick Short LinkedIn Tip During your Job Search💼🌐 #LinkedInTips #JobSearch #shorts', 'Published_Date': '2024-01-09T12:30:14Z', 'Duration': 'PT30S', 'Views': '84970', 'Likes': '8501', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'jnfyH1k2c38', 'Title': 'CSS Positioning Made Simple: A Beginner-Friendly Tutorial 🎨✨ | Tamil | EMC', 'Tags': ['css', 'positioning', 'tamil', 'tutorial', 'beginner', 'emc', 'errormakesclever', 'simple'], 'Thumbnail': 'https://i.ytimg.com/vi/jnfyH1k2c38/default.jpg', 'Description': '🚀 Master CSS Positioning in Tamil!🖥️✨ Explore essential techniques for web development, from absolute to relative positioning. 💻 Elevate your CSS skills and create visually stunning websites effortlessly. 🌐 Watch now to level up your web design game! 🔥 #css #positioning  #webdevelopment  #tamiltutorial  #emc #errormakesclever\n\nErrorMakesClever Instagram Link 👇👇👇\n https://www.instagram.com/errormakesclever\n\nErrorMakesClever Youtube Link 👇👇👇\nhttps://www.youtube.com/@ErrorMakesClever\n\nErrorMakesClever Whatsapp Channel Link 👇👇👇\nhttps://www.whatsapp.com/channel/0029VaARpx2F1YlQunv38L1Z', 'Published_Date': '2024-01-07T12:30:23Z', 'Duration': 'PT14M3S', 'Views': '19130', 'Likes': '975', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'cfCe3wNXtlE', 'Title': '🌐 Free Portfolio Templates for Stunning Resumes!! 📄 #shorts #portfolio #resume #templates #emc', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/cfCe3wNXtlE/default.jpg', 'Description': '🎨 Elevate your resume game with free portfolio templates! 🚀 Dive into our YouTube Shorts for a quick guide to top websites offering stunning designs. Craft a standout resume effortlessly! 💼✨ #PortfolioTemplates #ResumeDesign #Shorts', 'Published_Date': '2024-01-07T12:30:20Z', 'Duration': 'PT22S', 'Views': '125615', 'Likes': '15100', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'L-PxA7xa6UA', 'Title': 'High-Paying Jobs💼💸 2024 🌟: Your Road to Prosperity!', 'Tags': ['2024', 'highpaying', 'skills', 'jobs', 'emc', 'errormakesclever'], 'Thumbnail': 'https://i.ytimg.com/vi/L-PxA7xa6UA/default.jpg', 'Description': 'Explore the best-paying jobs of 2024 for a successful future!🌟Discover rewarding careers that bring prosperity and fulfillment. Start your journey now! 🚀💰 #shorts #highpayingskills #2024jobs #careersuccess #emc', 'Published_Date': '2024-01-05T12:30:11Z', 'Duration': 'PT1M', 'Views': '266690', 'Likes': '19549', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'J16CecpALAk', 'Title': 'Worried about getting job in 2024? #shorts  #nojob #highpayingskills #emc', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/J16CecpALAk/default.jpg', 'Description': '😟 Worried about getting a job in 2024? Watch this video where I provide insights about the job market. 🌐 Learn high-paying skills in the next 6 months and stand out from the crowd! 💼 #jobsearch #careeradvice', 'Published_Date': '2024-01-03T12:30:14Z', 'Duration': 'PT46S', 'Views': '155088', 'Likes': '14968', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '7dSJubxFWv0', 'Title': 'Front End Web Development Tutorial for Beginner | In Tamil | Final Project', 'Tags': ['errormakesclever', 'emc', 'frontend', 'tutorial', 'tamil', 'beginners', 'coding', 'project', 'webdevelopment'], 'Thumbnail': 'https://i.ytimg.com/vi/7dSJubxFWv0/default.jpg', 'Description': '🚀 Master Front-End Web Development with this Comprehensive Tutorial in Tamil! 🌐\n\n🕒 Timestamps:\n00:00 Introduction\n00:18 HTML Basics\n01:07:37 CSS Fundamentals\n02:11:28 CSS Positioning\n02:25:36 CSS Flexbox\n02:55:19 Media Queries\n03:19:42 JavaScript Essentials\n07:54:07 E-Commerce Project Showcase\n\n📚 Dive into the world of web development as we cover everything from HTML and CSS to advanced techniques like Flexbox and Media Queries. The tutorial is designed for beginners and tailored for Tamil-speaking audiences.\n\n💡 Highlights:\n- Learn HTML from scratch\n- Master CSS fundamentals and positioning\n- Explore the power of CSS Flexbox\n- Implement responsive design with Media Queries\n- Grasp the basics of JavaScript\n- Cap it off with a hands-on E-Commerce Project\n\n👨\u200d💻 Perfect for beginners and those looking to enhance their skills. Subscribe for regular updates and empower yourself to create stunning websites! 💻✨ #WebDevelopment #FrontEndDevelopment #TamilTutorial #CodingForBeginners', 'Published_Date': '2024-01-03T12:30:03Z', 'Duration': 'PT8H50M4S', 'Views': '145655', 'Likes': '5401', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'djbJjGp2tc8', 'Title': '2023 = Learning!', 'Tags': ['Emc', 'Error makes clever', 'success'], 'Thumbnail': 'https://i.ytimg.com/vi/djbJjGp2tc8/default.jpg', 'Description': 'We would like to hear from you 😊, Fill the below form \n\nhttps://forms.gle/VRdKySU1nc5J29A16', 'Published_Date': '2023-12-26T12:30:18Z', 'Duration': 'PT58S', 'Views': '299733', 'Likes': '27397', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '1h35ad0yn-w', 'Title': 'Don’t miss this hack ! Try it. #linkedin #trick', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/1h35ad0yn-w/default.jpg', 'Description': '', 'Published_Date': '2023-12-23T10:18:26Z', 'Duration': 'PT28S', 'Views': '65677', 'Likes': '6954', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '_pqX3eIOQ9k', 'Title': 'DAY-14 LINUX:operating system is the software that directly manages a system hardware and resources', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/_pqX3eIOQ9k/default.jpg', 'Description': '', 'Published_Date': '2023-12-20T12:34:11Z', 'Duration': 'PT37S', 'Views': '65822', 'Likes': '7018', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'kkn0pnLqaco', 'Title': 'DAY-13 WWW: A system of interconnected public webpages accessible through the Internet#emc#tech#www', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/kkn0pnLqaco/default.jpg', 'Description': '', 'Published_Date': '2023-12-19T13:14:04Z', 'Duration': 'PT59S', 'Views': '30806', 'Likes': '2997', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'hVWhsHOQbXM', 'Title': 'Learn CSS Flexbox with Project | Flex Tutorial | Web Development Project | EMC | In Tamil', 'Tags': ['css', 'flexbox', 'css layout', 'css in tamil', 'learn css', 'flexbox tutorial', 'tamil tutorial'], 'Thumbnail': 'https://i.ytimg.com/vi/hVWhsHOQbXM/default.jpg', 'Description': "Next Full Stack Web Development Batch Registration Link:\nhttps://bitly.ws/YAsk\n\nFor course related queries contact us:\n📞 8270496560\n✉️ errormakesclever@gmail.com\n\nFollow us on LinkedIn to get more updates on Tech:\nhttps://www.linkedin.com/company/errormakesclever/\n\nJoin 500k+ Instagram Community:\nhttps://www.instagram.com/errormakesclever/\n\n🚀 Mastering CSS Flexbox Tutorial: Dive into the world of flexible layouts with our comprehensive guide to CSS Flexbox! In this tutorial, we'll demystify Flexbox, the powerful layout model that makes designing responsive and dynamic web pages a breeze. Learn how to create complex and adaptive layouts with ease, as we cover Flex containers, items, alignment, ordering, and more. Whether you're a beginner or looking to enhance your front-end skills, this tutorial provides clear explanations, practical examples, and tips to elevate your CSS game. Watch, code along, and unlock the potential of Flexbox for creating modern, responsive web designs! 💻🎨 #CSSFlexbox #WebDesign #CSSLayout", 'Published_Date': '2023-12-16T05:51:57Z', 'Duration': 'PT30M', 'Views': '33682', 'Likes': '1255', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'qbl7tOaQF20', 'Title': 'Websites for Project Ideas, Make use of it ! #shorts #emc', 'Tags': ['website for project', 'project ideas', 'new project'], 'Thumbnail': 'https://i.ytimg.com/vi/qbl7tOaQF20/default.jpg', 'Description': '', 'Published_Date': '2023-12-13T12:30:25Z', 'Duration': 'PT29S', 'Views': '107909', 'Likes': '9234', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'JHHBOLBt1JI', 'Title': 'ATS Resume Tool is here 👆👆 #resume #ats', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/JHHBOLBt1JI/default.jpg', 'Description': '', 'Published_Date': '2023-12-12T13:46:08Z', 'Duration': 'PT27S', 'Views': '200054', 'Likes': '19219', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '6ImT0CuJVX4', 'Title': 'A Journey from Non-IT to IT Industry 🚀| Zero Coding Experience | EMC Academy Student Podcast', 'Tags': ['emc', 'errormakesclever', 'review', 'emc review', 'full stack web development', 'tamil emc', 'tamil course', 'non it to it', 'non technical', 'zero coding', 'non technical to technical', 'placed', 'lpa', 'highest package', 'emc student'], 'Thumbnail': 'https://i.ytimg.com/vi/6ImT0CuJVX4/default.jpg', 'Description': "Next Full Stack Web Development Batch Registration Link:\nhttps://bitly.ws/YAsk\n\nFor course related queries contact us:\n📞 8270496560\n✉️ errormakesclever@gmail.com\n\nFollow us on LinkedIn to get more updates on Tech:\nhttps://www.linkedin.com/company/errormakesclever/\n\nJoin 500k+ Instagram Community:\nhttps://www.instagram.com/errormakesclever/\n\nMustafa LinkedIn Id:\nhttps://www.linkedin.com/in/musthafa2324\n\nDive into our latest podcast episode, where we share the incredible journey of someone who went from knowing nothing about IT to landing a job in the industry. This person, who studied at the Error Makes Clever Academy, talks about their experience in a Full Stack Web Development course.\n\nIn this podcast, we explore how an average student with a BA in Religious Studies transformed their career by learning to code with us. You'll hear about the challenges they faced, how they built a strong resume, and the LinkedIn hacks that helped them stand out in the job market.\n\nDiscover how Error Makes Clever Academy's unique approach helps students, even those without a technical background, secure placements in the IT field. We discuss the importance of developing skills, effective networking, and the commitment to continuous learning.\n\nWhether you're considering a career change or just want to boost your skills, this podcast is a valuable guide. Join us as we talk about non-technical beginnings, the journey from zero coding to a confident IT professional, and how you can take the first steps toward a successful career switch. Don't miss out on insights that could transform your career in the IT industry.", 'Published_Date': '2023-12-12T04:44:56Z', 'Duration': 'PT23M37S', 'Views': '40179', 'Likes': '1861', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '1Z4itB15U_s', 'Title': 'DAY 12 : Data structures - a specific way of organizing data in a specialized format on a computer', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/1Z4itB15U_s/default.jpg', 'Description': '', 'Published_Date': '2023-12-04T03:32:44Z', 'Duration': 'PT44S', 'Views': '153699', 'Likes': '8740', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'iBEAquFXHWg', 'Title': 'DAY 11 -Docker:A open platform for developing, Shipping and Running Applications #shorts #emc #tech', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/iBEAquFXHWg/default.jpg', 'Description': 'DAY 11 -Docker:A open platform for developing, Shipping and Running Applications #shorts #emc #tech', 'Published_Date': '2023-12-01T15:24:34Z', 'Duration': 'PT47S', 'Views': '113620', 'Likes': '10414', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '9SwNLkRmg7Y', 'Title': 'DAY 10 - API : Obtaining data from another application is done through something#shorts #emc #tech', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/9SwNLkRmg7Y/default.jpg', 'Description': 'DAY 10 - API : Obtaining data from another application is done through something is API', 'Published_Date': '2023-11-28T12:30:05Z', 'Duration': 'PT49S', 'Views': '46016', 'Likes': '4139', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '9cQaOXgi8XQ', 'Title': 'DAY 9: "LLM" - Explore Language Model in a snap! #emc #tech #llm #ai', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/9cQaOXgi8XQ/default.jpg', 'Description': 'DAY 9: "LLM" - Explore Language Model in a snap!', 'Published_Date': '2023-11-27T12:30:04Z', 'Duration': 'PT57S', 'Views': '85223', 'Likes': '7917', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'ytQQ1TXz-CI', 'Title': 'DAY 8-Dive into the world of data Engineering-where insights meet innovation #shorts #emc #tech', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/ytQQ1TXz-CI/default.jpg', 'Description': '', 'Published_Date': '2023-11-23T12:31:23Z', 'Duration': 'PT44S', 'Views': '59022', 'Likes': '5582', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 't22s6omEr4M', 'Title': 'DAY 7 :virtualization -Learn the efficiency of virtual environments #shorts #emc #tech', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/t22s6omEr4M/default.jpg', 'Description': 'DAY 7 :VIRTUALIZATION', 'Published_Date': '2023-11-22T12:30:35Z', 'Duration': 'PT48S', 'Views': '53570', 'Likes': '5218', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'FZmR_m0KuC8', 'Title': 'Day 6 : Battle of Minds: Machine learning Vs Deep learning in 100 bytes #shorts #EMC #tech', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/FZmR_m0KuC8/default.jpg', 'Description': 'Day 6 : Battle of Minds: Machine learning Vs Deep learning', 'Published_Date': '2023-11-20T12:30:12Z', 'Duration': 'PT45S', 'Views': '63322', 'Likes': '6186', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'Xd0uGWDrVXI', 'Title': 'DAY 5 : IP Address - Devices communicate across the vast landscape of world wide web #EMC #shorts', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/Xd0uGWDrVXI/default.jpg', 'Description': 'DAY 5 : IP Address Explanation', 'Published_Date': '2023-11-18T12:48:02Z', 'Duration': 'PT59S', 'Views': '128710', 'Likes': '8828', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'CsnEBjbdO7g', 'Title': 'DAY 4- BIG DATA : From bytes to breakthroughs,a journey into the heart of innovation.#EMC #shorts', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/CsnEBjbdO7g/default.jpg', 'Description': 'DAY 4- Explaining BIG DATA', 'Published_Date': '2023-11-17T12:30:11Z', 'Duration': 'PT53S', 'Views': '43595', 'Likes': '4199', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'sJSucvrMp80', 'Title': "Day 3 : Navigating the web's secret passages with the cloak of VPN invisibility #shorts #vpn #EMC", 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/sJSucvrMp80/default.jpg', 'Description': 'Day 3/30 - Explaining VPN', 'Published_Date': '2023-11-17T04:30:15Z', 'Duration': 'PT54S', 'Views': '60047', 'Likes': '5289', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'gUMbjfuudZ0', 'Title': 'Day 2 : RAM : The silent hero fueling your digital adventures! #errormakesclever #tech #shorts', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/gUMbjfuudZ0/default.jpg', 'Description': 'Day 2/30 - RAM explanation', 'Published_Date': '2023-11-16T12:30:31Z', 'Duration': 'PT53S', 'Views': '166672', 'Likes': '16599', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'xZZrnDtK0qc', 'Title': 'Empower your plants with a voice! Watch them thrive and speak their needs! #shorts #iot', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/xZZrnDtK0qc/default.jpg', 'Description': 'Bringing my plants into the digital age with IoT magic!', 'Published_Date': '2023-11-15T12:30:36Z', 'Duration': 'PT50S', 'Views': '134149', 'Likes': '11643', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '6RmVZ4yRKeE', 'Title': 'Full Stack Web Development Course | MERN | 3 Months Course by Error Makes Clever', 'Tags': ['full stack', 'tamil', 'course', '3 months', 'learn', 'master', 'best'], 'Thumbnail': 'https://i.ytimg.com/vi/6RmVZ4yRKeE/default.jpg', 'Description': "Registration Link: https://bitly.ws/YAsk\nContact: 8270496560 for any queries \n\nUnlock Your Full Stack Potential - Enroll Now at a Special Rate!\nHi there,\nHope this message finds you well!\n\n🚀 Exciting News: Our Full Stack Web Development course is set to kick off on November 6, and we're thrilled to invite you to be a part of it!\n\n🔥 Act Fast - Limited-Time Offer: To celebrate the launch, we're offering an exclusive discounted rate of ₹14,999 instead of the original ₹17,777 for the first 50 registrations! Secure your spot now and dive into the world of Full Stack development without breaking the bank.\n\n🌐 Why Full Stack? Our comprehensive course covers everything from front-end design to back-end functionality, ensuring you gain mastery in every aspect of web development. Whether you're a beginner or looking to level up your skills, our program is designed to empower you with the knowledge and tools needed for success in the dynamic field of Full Stack Web Development.\n\n💡 What's in Store for You?\n- Hands-on learning with industry-relevant projects\n- Expert-led sessions to guide you at every step\n- Access to a lifetime of recorded sessions for continuous learning\n- Full job assistance, from resume building to LinkedIn optimization\n\n🎓 Don't Miss Out: With seats filling up fast, this is your chance to join a vibrant community of learners and professionals. Embrace the opportunity to boost your career with in-demand Full Stack skills.\n\n🚨 Act Now: Register before November 6 to lock in the special rate of ₹14,999 and secure your place in our upcoming Full Stack Web Development class. Time is ticking, and we don't want you to miss out on this fantastic offer!\n\nReady to embark on your Full Stack journey? Click https://bitly.ws/YAsk to enroll now.\n\nSee you in class, where innovation meets development!", 'Published_Date': '2023-10-31T04:20:05Z', 'Duration': 'PT3M35S', 'Views': '72295', 'Likes': '2812', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'Omu2WhkoydU', 'Title': 'Who is the world first programmer? #adalovelace #worldfirstprogrammer #code', 'Tags': ['Ada lovelace', 'programmer', 'charles babbage', 'computer'], 'Thumbnail': 'https://i.ytimg.com/vi/Omu2WhkoydU/default.jpg', 'Description': 'Who holds the title of the world\'s first programmer? Ada Lovelace earns that distinction, having collaborated with Charles Babbage, widely recognized as the father of computer. Ada\'s pioneering contributions laid the groundwork for the modern computer. Every second Tuesday of October, Ada Lovelace Day celebrates her legacy, inspiring women to pursue science, math, and engineering. Follow for more insightful content like this. 🖥️👩\u200d💻 #AdaLovelace #PioneerOfProgramming #WomenInSTEM #TechInnovation"', 'Published_Date': '2023-10-28T14:19:33Z', 'Duration': 'PT49S', 'Views': '59785', 'Likes': '5400', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'eIwJZBzT7fg', 'Title': 'Client side rendering Vs Server side rendering explained #web', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/eIwJZBzT7fg/default.jpg', 'Description': '', 'Published_Date': '2023-10-18T12:47:09Z', 'Duration': 'PT58S', 'Views': '48787', 'Likes': '4255', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'poo0BXryffI', 'Title': 'JavaScript tutorial for Beginners in Tamil | DOM Explained | Mini Project in JavaScript', 'Tags': ['javascript', 'javascript tutorial for beginners', 'javascript in tamil', 'tamil programming', 'javascript made easy', 'build a mini project using javascript', 'javascript essentials', 'javascript programming'], 'Thumbnail': 'https://i.ytimg.com/vi/poo0BXryffI/default.jpg', 'Description': "MERN STACK DEVELOPMENT COURSE \npre-registration link: https://forms.gle/91gEAibDD5EVk7aP7\n\nTimestamps:\n\n00:00 - Intro\n00:52 - Course Preview\n01:24 - JavaScript Intro\n02:34 - Variables\n22:12 - Keywords\n23:09 - Comments\n24:35 - Operators\n31:43 - DataTypes\n34:47 - Functions and Exercise\n58:25 - if else and Exercise\n01:18:48 - For Loop\n01:30:40 - Dom Manipulation \n01:43:00 - Dom Events and Exercise\n02:05:55 - Random Numbers \n02:23:10 - DOM Style Manipulation \n02:28:30 - Task1 \n02:33:18 - Task2\n02:41:05 - Task3\n02:42:37 - Task4\n02:50:01 - Task5\n02:56:10 - Todo List\n03:36:10 - Booksky Project\n04:34:35 - End\n\nIn this insightful YouTube video, I delve into the fundamentals of JavaScript, focusing on its Document Object Model (DOM) and basic programming concepts. Join me on a journey through JavaScript's core principles, and discover how to leverage DOM for dynamic web development. Whether you're a beginner or looking to reinforce your programming skills, this tutorial provides a clear and engaging overview of JavaScript essentials, accompanied by practical examples to enhance your understanding. Uncover the power of JavaScript and kickstart your programming journey with confidence! \n\nHappy Learning !", 'Published_Date': '2023-10-11T11:08:24Z', 'Duration': 'PT4H35M10S', 'Views': '368905', 'Likes': '9152', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'sSKFx39UUpk', 'Title': 'Automate Job Apply process using AI #ai #resume #job', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/sSKFx39UUpk/default.jpg', 'Description': '', 'Published_Date': '2023-10-10T14:27:31Z', 'Duration': 'PT41S', 'Views': '112179', 'Likes': '12758', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'l4y5flTC1g4', 'Title': 'Explore the opportunities as a wordpress developer 🚀 #wordpress', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/l4y5flTC1g4/default.jpg', 'Description': '', 'Published_Date': '2023-10-07T12:51:17Z', 'Duration': 'PT29S', 'Views': '78603', 'Likes': '7750', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'GnOSxrLh3_0', 'Title': '#11 Understanding SQL Primary Key | SQL tutorial for beginners | in tamil', 'Tags': ['SQL', 'Primary Keys', 'Database Design', 'Data Integrity', 'SQL Tutorial', 'Database Management', 'SQL Tips', 'Database Development', 'SQL Queries', 'SQL Server', 'MySQL', 'PostgreSQL', 'Database Fundamentals', 'Data Management', 'Programming', 'Coding', 'Tech Tutorial', 'SQL Skills', 'SQL Mastery', 'SQL Best Practices.'], 'Thumbnail': 'https://i.ytimg.com/vi/GnOSxrLh3_0/default.jpg', 'Description': "Welcome to our SQL tutorial on Primary Keys! In this video, we'll dive deep into the concept of Primary Keys in SQL databases. Whether you're a beginner looking to learn the fundamentals or an experienced developer seeking a refresher, this tutorial is for you.\n\n🔑 What You'll Learn:\n- What is a Primary Key and why is it essential in database design.\n- How to define a Primary Key in SQL tables.\n- The role of Primary Keys in ensuring data integrity.\n- Practical examples and best practices for using Primary Keys.\n- Common mistakes to avoid when working with Primary Keys.\n\nBy the end of this video, you'll have a solid understanding of SQL Primary Keys and how to implement them effectively in your database projects. Whether you're using MySQL, PostgreSQL, SQL Server, or another SQL database system, the principles covered here will apply.\n\nDon't forget to like, share, and subscribe for more informative SQL tutorials! If you have any questions or topics you'd like us to cover in future videos, please leave them in the comments section below.\n\nThanks for watching, and let's get started on our journey to becoming SQL experts! 🔍📊💡\n\n#SQL #PrimaryKeys #DatabaseDesign #SQLTutorial #DataIntegrity #DatabaseManagement", 'Published_Date': '2023-10-06T13:43:38Z', 'Duration': 'PT8M34S', 'Views': '8774', 'Likes': '252', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'tcjcjHX9wcA', 'Title': '#10 SQL 25 Practice Questions | DDL, DML, DQL, Group by, Having | SQL Tutorial for beginners | tamil', 'Tags': ['SQL', 'Database', 'DDL', 'DQL', 'DML', 'GROUP BY', 'HAVING Clause', 'DataQuery', 'DataManipulation', 'DatabaseSkills', 'SQLTutorial', 'SQLQuestions', 'SQLAnswers', 'DatabaseManagement', 'SQLTips', 'SQLLearning', 'SQLMastery', 'DataAnalysis', 'SQLInterview', 'SQLQueries', 'SQLBasics', 'DatabaseDevelopment', 'SQLTraining', 'SQLForBeginners', 'SQLKnowledge', 'SQLExperts'], 'Thumbnail': 'https://i.ytimg.com/vi/tcjcjHX9wcA/default.jpg', 'Description': "Unlock the power of SQL with our comprehensive guide! In this in-depth video tutorial, we cover 25 fundamental SQL questions and answers that encompass Data Definition Language (DDL), Data Query Language (DQL), Data Manipulation Language (DML), GROUP BY, and the HAVING clause. Whether you're a beginner looking to learn SQL from scratch or an experienced developer looking to sharpen your SQL skills, this video has something for everyone.\n\nHere's what you can expect from this tutorial:\n- **DDL:** Discover how to create, modify, and manage database structures like a pro.\n- **DQL:** Learn the art of querying data with SELECT statements and filtering your results effectively.\n- **DML:** Master the skills needed to insert, update, and delete data while maintaining data integrity.\n- **GROUP BY:** Dive deep into grouping and aggregating data to gain valuable insights.\n- **HAVING Clause:** Explore how to filter grouped data and harness its power for advanced analysis.\n\nEach SQL question is meticulously explained with clear examples and detailed answers, ensuring you understand the core concepts and best practices. Whether you're preparing for an interview, enhancing your database skills, or simply curious about SQL, this video is your one-stop resource.\n\nDon't miss out on this opportunity to become a SQL expert! Hit the play button now and level up your database skills. If you find this video helpful, please like, share, and subscribe for more informative tutorials on SQL and database management.", 'Published_Date': '2023-10-05T12:30:28Z', 'Duration': 'PT33M13S', 'Views': '18464', 'Likes': '515', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'e_su8zuTtMo', 'Title': 'Tips for youtube learners 🚀💥', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/e_su8zuTtMo/default.jpg', 'Description': '', 'Published_Date': '2023-10-04T12:30:22Z', 'Duration': 'PT32S', 'Views': '324994', 'Likes': '45696', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '5682golSP5I', 'Title': '#9 SQL Having clause Explained | in Tamil | SQL A-Z tutorial series for beginners', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/5682golSP5I/default.jpg', 'Description': "In the world of SQL, the `HAVING` clause is a powerful tool that helps us filter and manipulate data in a way that the `WHERE` clause can't quite manage. While the `WHERE` clause filters rows based on conditions applied to individual records, the `HAVING` clause comes into play when we want to filter the results of aggregated data, typically from `GROUP BY` operations.\n\nThink of it like this: the `WHERE` clause is your gatekeeper for individual rows, deciding which rows make it into the result set. In contrast, the `HAVING` clause acts as a bouncer for aggregated data, letting you control which groups of data get to join the party in your final result set.\n\nHere's what you'll learn in this video:\n\n1. **The Basics**: I'll start by explaining the basic syntax of the `HAVING` clause and how it's used in conjunction with the `GROUP BY` clause.\n\n2. **Aggregation**: We'll explore the power of aggregation functions like `SUM`, `COUNT`, `AVG`, and `MAX`, and see how they're often paired with `HAVING` to filter summarized data.\n\n3. **Examples**: I'll provide real-world examples to illustrate when and why you'd want to use `HAVING`, such as finding customers who've made more than a certain number of purchases or products with a certain sales threshold.\n\n4. **Comparison with WHERE**: We'll draw a clear distinction between the `HAVING` and `WHERE` clauses, so you'll know exactly when to use each.\n\nBy the end of this video, you'll have a solid grasp of how the `HAVING` clause is your go-to tool for filtering and shaping summarized data in SQL. It's a must-know for anyone working with databases, especially when dealing with reporting and analytics. So, if you're ready to level up your SQL skills, hit that play button and let's dive into the world of SQL's `HAVING` clause!\n\nDon't forget to like this video, subscribe to our channel, and hit the notification bell to stay updated with more database tutorials and tips. Let's get started! 🚀", 'Published_Date': '2023-09-28T06:32:11Z', 'Duration': 'PT4M48S', 'Views': '13435', 'Likes': '299', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'Y7Kqbc0sDGI', 'Title': '#8 SQL Group by and Order by | SQL A-Z Tutorial Series | for beginners in tamil | EMC', 'Tags': ['SQL', 'Database Management', 'Data Analysis', 'SQL Tutorial', 'Group By', 'Order By', 'SQL Examples', 'SQL Queries', 'Database', 'Sorting Data', 'Data Organization', 'SQL Basics', 'Query Optimization', 'SQL Commands', 'Data Sorting', 'SQL Grouping', 'SQL Training', 'Data Manipulation', 'SQL Tips', 'SQL Tricks'], 'Thumbnail': 'https://i.ytimg.com/vi/Y7Kqbc0sDGI/default.jpg', 'Description': '🎥 Explore SQL - Group By and Order By with Examples 📊\n\nWelcome to our SQL tutorial series! In this video, we\'ll dive into the powerful SQL commands "GROUP BY" and "ORDER BY" with real-world examples. \n\nIn the world of databases, understanding how to group and order your data is crucial, and we\'ve got you covered. Whether you\'re a beginner or looking to refresh your SQL skills, this tutorial is for you.\n\n🔍 What You\'ll Learn:\n- How to group your data based on specific criteria.\n- Sorting your results in ascending and descending order.\n- Practical examples to solidify your understanding.\n- Tips and tricks for optimizing your SQL queries.\n\n🚀 Get ready to unlock the full potential of SQL for data analysis and database management.\n\n👍 Don\'t forget to like, share, and subscribe to our channel for more SQL tutorials and data-related content!\n\n💬 Got questions or suggestions? Drop them in the comments below, and we\'ll be there to assist you.\n\n#SQL #DatabaseManagement #DataAnalysis #SQLTutorial #GroupBy #OrderBy #SQLExamples', 'Published_Date': '2023-09-25T13:24:05Z', 'Duration': 'PT25M27S', 'Views': '18854', 'Likes': '464', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '4igiQuJaifU', 'Title': 'Focus on one programming language 🙌 #programming #coding', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/4igiQuJaifU/default.jpg', 'Description': '', 'Published_Date': '2023-09-23T14:39:26Z', 'Duration': 'PT40S', 'Views': '808878', 'Likes': '66141', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 't8VY9kaM_t0', 'Title': 'Build your LinkedIn connections 🚀🙌', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/t8VY9kaM_t0/default.jpg', 'Description': '', 'Published_Date': '2023-09-21T14:41:04Z', 'Duration': 'PT39S', 'Views': '250953', 'Likes': '24126', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '-FfEiNu2ar8', 'Title': '#7 Aggregate Functions in SQL | SQL Tutorial for Beginners Series | SQL in Tamil | EMC', 'Tags': ['SQL', 'AggregateFunctions', 'DataAnalysis', 'SQLTutorial', 'DatabaseManagement', 'TechSkills', 'SQLTips', 'DataSummarization', 'SQLFunctions', 'SQLQueries', 'DatabaseAnalysis', 'SQLCalculations', 'DatabaseInsights', 'SQLLearning', 'DatabaseDevelopment', 'SQLMastery', 'DataAnalytics', 'SQLQuerying', 'DatabaseSkills', 'SQLExamples'], 'Thumbnail': 'https://i.ytimg.com/vi/-FfEiNu2ar8/default.jpg', 'Description': "Discover the power of SQL Aggregate Functions in our latest YouTube video! 📊\n\n🚀 In this tutorial, we delve into the world of SQL and explore five fundamental aggregate functions: COUNT, SUM, AVG, MAX, and MIN.\n\n💡 Uncover the secrets of data summarization, calculation, and analysis as we break down each function with practical examples and explanations.\n\n🔍 Learn how to harness the full potential of these functions to extract meaningful insights from your database and streamline your data-related tasks.\n\n📋 Whether you're a data enthusiast, analyst, or database developer, this video is your key to unlocking advanced SQL capabilities.\n\n📲 Don't forget to like, subscribe, and hit that notification bell to stay updated with more SQL tutorials and tips! 💬📚\n\n#SQL #AggregateFunctions #DataAnalysis #SQLTutorial #DatabaseManagement #TechSkills #SQLTips\n\n[Insert your social media links and a call to action here]", 'Published_Date': '2023-09-21T14:39:28Z', 'Duration': 'PT8M18S', 'Views': '18909', 'Likes': '403', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'uhWu8JBRIa0', 'Title': '#6 SQL Practice Questions | SQL A-Z Tutorial Series | Sql for beginners full tutorial in tamil', 'Tags': ['SQL Practice', 'SQL Questions', 'SQL Tutorial', 'DDL Commands', 'DML Commands', 'Database Management', 'SQL Queries', 'Learn SQL', 'SQL Fundamentals', 'SQL Basics', 'SQL Skills', 'Database Design', 'SQL Training', 'SQL Tips', 'SQL Simplified', 'SQL Made Easy', 'SQL Mastery', 'Database Solutions', 'SQL Problem Solving', 'SQL Help', 'SQL Study', 'SQL Test', 'SQL Quiz', 'SQL Lessons', 'Database Practice', 'SQL Demystified'], 'Thumbnail': 'https://i.ytimg.com/vi/uhWu8JBRIa0/default.jpg', 'Description': "Check out our latest YouTube video where we tackle 13 SQL practice questions, breaking down each one with a clear and concise explanation. 📚\n\n🔍 Dive into the world of SQL as we unravel the power of DDL (Data Definition Language) and DML (Data Manipulation Language) commands through simple yet essential questions.\n\n💡 Enhance your SQL skills, master database management, and understand how to create, modify, and query data effectively.\n\n🚀 Whether you're a beginner looking for foundational SQL knowledge or seeking a quick refresher, this video has got you covered!\n\n📋 Don't forget to like, subscribe, and hit that notification bell to stay updated with more SQL tutorials and practice questions! 📲💬\n\n#SQLPractice #DDLCommands #DMLCommands #SQLQueries #DatabaseManagement #SQLTutorial #TechEducation\n\n[Insert your social media links and a call to action here]", 'Published_Date': '2023-09-19T12:37:45Z', 'Duration': 'PT18M6S', 'Views': '29884', 'Likes': '632', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '_m7ap8EvAEM', 'Title': 'Stop complaining and Start Doing 🚀💥 #money', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/_m7ap8EvAEM/default.jpg', 'Description': '', 'Published_Date': '2023-09-18T12:30:14Z', 'Duration': 'PT40S', 'Views': '132189', 'Likes': '15751', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'xPhImdnkJyo', 'Title': '#5 DML Commands in SQL | Insert, Update, Delete, Select | sql tutorial for beginners in tamil', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/xPhImdnkJyo/default.jpg', 'Description': "Unlock the power of SQL Data Manipulation Language (DML) commands and SELECT statements with our comprehensive YouTube tutorial! 🚀\n\n🔥 Dive into the world of SQL as we cover the essential DML commands: INSERT, UPDATE, DELETE, and SELECT. Learn how to manipulate data and query your database like a pro.\n\n💡 Discover the art of retrieving specific information from your database with the SELECT command. We'll walk you through various querying techniques and practical examples.\n\n🛠️ Get hands-on experience with real-world scenarios, and master the skills you need for effective data management and analysis.\n\n👩\u200d💻 Whether you're a beginner looking to start your SQL journey or an experienced user seeking to refine your skills, this tutorial has something for everyone.\n\n📋 Don't forget to like, subscribe, and hit that notification bell to stay updated with more SQL tutorials and tips! 📲💬\n\n#SQL #DataManipulation #SELECTCommand #DMLCommands #DatabaseQuery #SQLTutorial #TechSkills", 'Published_Date': '2023-09-18T12:20:19Z', 'Duration': 'PT16M24S', 'Views': '40060', 'Likes': '878', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'zHjpQnmA9sg', 'Title': '#4 DDL Commands | A Short & Crisp Tutorial with Examples | In Tamil | SQL | Error Makes Clever', 'Tags': ['SQL', 'DatabaseManagement', 'DDLCommands', 'Tutorial', 'TechTips', 'SQLBasics', 'DatabaseDesign', 'SQLTutorial', 'LearnSQL', 'DataManagement', 'DatabaseAdmin', 'StructuredQueryLanguage', 'DatabaseStructure', 'DatabaseDevelopment', 'SQLCommands', 'SQLSyntax', 'SQLExamples', 'DatabaseTutorial', 'CodingTutorial', 'DatabaseSchema', 'DatabaseTables', 'SQLPro', 'TechLearning', 'DataManipulation', 'DatabaseFundamentals', 'DDLSQL', 'DatabaseSkills', 'DatabaseCreation', 'SQLQueries', 'TechEducation'], 'Thumbnail': 'https://i.ytimg.com/vi/zHjpQnmA9sg/default.jpg', 'Description': "In this concise YouTube tutorial, dive into the world of Database Definition Language (DDL) commands and become a SQL pro! 💻\n\n🔍 Explore the fundamental DDL commands: CREATE, ALTER, and DROP, and discover how they shape the structure of your database.\n\n🚀 Follow along with real-world examples and step-by-step explanations that demystify DDL commands.\n\n📋 Learn how to create tables, modify their structure, and gracefully remove them using SQL DDL commands.\n\n🎯 Whether you're a beginner or a seasoned SQL user, this tutorial will help you sharpen your skills and harness the power of DDL commands for database management.\n\n💡 Don't forget to like, subscribe, and hit that notification bell to stay updated with more tech tutorials and tips! 📲💬\n\n#SQL #DatabaseManagement #DDLCommands #Tutorial #techtips \n\nJoin our instagram community\nhttps://www.instagram.com/errormakesclever/", 'Published_Date': '2023-09-14T06:49:19Z', 'Duration': 'PT13M6S', 'Views': '59062', 'Likes': '1405', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'gsvYvufx1e0', 'Title': '#3 How to Install MySQL | SQL Tutorial Series | Error Makes Clever | in Tamil', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/gsvYvufx1e0/default.jpg', 'Description': 'Here i have just mentioned the steps to download and install mysql to follow along with me in this sql series. \n\nJoin our 500k+ Instagram community \nhttps://www.instagram.com/errormakesclever/', 'Published_Date': '2023-09-14T06:49:15Z', 'Duration': 'PT4M46S', 'Views': '53038', 'Likes': '1070', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'y31EUnxHLJE', 'Title': 'Kutty story of Internet 🌍 ! #internet', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/y31EUnxHLJE/default.jpg', 'Description': '', 'Published_Date': '2023-09-12T13:00:09Z', 'Duration': 'PT1M1S', 'Views': '76923', 'Likes': '6564', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# ...
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'Rtmgt2Qfqr4', 'Title': '#02 Variables and DataTypes Explained 🔋| In Tamil | Python Tutorial Series 🚀| EMC Academy', 'Tags': ['Python', 'Python in tamil', 'python tutorial in tamil', 'Python variables and datatypes', 'how to code', 'variables and datatypes in python', 'variables explained', 'datatypes explained', 'python tutorial series', 'emc academy', 'errormakescleveracademy'], 'Thumbnail': 'https://i.ytimg.com/vi/Rtmgt2Qfqr4/default.jpg', 'Description': "In this particular video, we'll be exploring the basics of Python programming language, specifically the concepts of variables, data types, and operators.\n\nPython is a high-level, interpreted programming language that is widely used in many different fields, including web development, data science, and machine learning. Understanding the fundamentals of Python is essential for anyone looking to pursue a career in these areas.\n\nWe'll start by discussing variables, which are used to store values in Python. We'll cover how to declare and initialize variables, as well as how to assign and reassign values to them.\n\nNext, we'll move on to data types, which are used to define the type of data that a variable can hold. Python has several built-in data types, including integers, floats, strings, and booleans. We'll explore each of these in detail and discuss how to convert between them.\n\nFinally, we'll discuss operators, which are used to perform operations on variables and data. Python has several different types of operators, including arithmetic operators, comparison operators, and logical operators. We'll demonstrate how each of these operators works and provide examples of how to use them in your own code.\n\nBy the end of this video, you'll have a solid understanding of Python variables, data types, and operators, and be well on your way to becoming a proficient Python programmer.\n\nPython in Tamil \n\nJoin Our 70k+ Instagram Community \n\nhttps://instagram.com/errormakesclever?igshid=NTc4MTIwNjQ2YQ==", 'Published_Date': '2023-05-08T04:30:12Z', 'Duration': 'PT8M48S', 'Views': '159834', 'Likes': '6846', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'BVIoAILnZ4Q', 'Title': '#01 Python Programming Tutorial Series 📚| Introduction to Python 🧑\u200d💻| EMC ACADEMY 💪', 'Tags': ['Python', 'Python tutorial in tamil', 'programming in tamil', 'programming playlist', 'programming for beginners', 'python for beginners in tamil', 'python tamil', 'learn python in tamil', 'programming in 30 days', 'python', 'Python developer', 'you can become a python developer', 'how to become a python developer', 'how to code', 'coding tamil', 'brototype coding', 'learn coding fully'], 'Thumbnail': 'https://i.ytimg.com/vi/BVIoAILnZ4Q/default.jpg', 'Description': "Welcome to our Python tutorial series on YouTube! In this series, I will be teaching you Python programming language from scratch in a fun and easy way. Python is a versatile and powerful programming language that is used in a variety of industries, from web development to data science and machine learning. \n\nWhether you're a complete beginner or already have some programming experience, this series is designed to help you learn Python step by step, with clear explanations and practical examples. My goal is to make the learning process enjoyable and accessible, so that you can build a solid foundation in Python and start using it to create your own projects.\n\nSo, get ready to dive into the exciting world of Python with me! We'll cover everything from the basics of Python syntax to advanced topics like object-oriented programming, file handling, and web scraping. By the end of this series, you'll have a thorough understanding of Python and be able to apply your skills to real-world projects. Let's get started!\n\nEverything in Tamil. \n\nJoin our 46K+ Instagram community\n\nhttps://instagram.com/errormakesclever?igshid=NTc4MTIwNjQ2YQ==", 'Published_Date': '2023-05-07T03:30:06Z', 'Duration': 'PT1M53S', 'Views': '241477', 'Likes': '10272', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'Y0RoLM48xP4', 'Title': 'You can never learn coding if you don’t practice. Start practising coding in these websites. #code', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/Y0RoLM48xP4/default.jpg', 'Description': '', 'Published_Date': '2023-05-04T02:58:09Z', 'Duration': 'PT23S', 'Views': '765792', 'Likes': '84597', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 't_WIjhkZNoA', 'Title': 'Should you really take 30k worth course ? #training #trainingcenter', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/t_WIjhkZNoA/default.jpg', 'Description': '', 'Published_Date': '2023-05-03T02:30:23Z', 'Duration': 'PT44S', 'Views': '172378', 'Likes': '20434', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'jk7q7QTFnvI', 'Title': 'How to get google, Microsoft, IBM certificates for free ? . Try this 😉', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/jk7q7QTFnvI/default.jpg', 'Description': '', 'Published_Date': '2023-05-01T12:30:17Z', 'Duration': 'PT50S', 'Views': '450020', 'Likes': '47597', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '5QzzeYHApV0', 'Title': 'How to become a full stack developer 🚀 | Web Development Explained | Error Makes Clever Academy', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/5QzzeYHApV0/default.jpg', 'Description': 'In this video, I will explain what full stack development is and provide a detailed overview of the technologies used to build full stack web applications. Full stack web development involves building the front-end, back-end, and database components of a web application. This means that full stack developers are responsible for everything from designing the user interface to managing the server-side logic and database.\n\nI will begin by discussing the key technologies and programming languages used in full stack web development, including HTML, CSS, JavaScript, Node.js, and various front-end frameworks such as React and Angular. I will then move on to discuss the server-side technologies like Python, Java and Node Js, and databases like MySQL, MongoDB, and Aws.\n\nThroughout the video, I will provide examples and code snippets to help illustrate how these different technologies are used in practice.\n\nBy the end of this video, you will have a comprehensive understanding of what full stack web development is and the tools and technologies used by full stack developers to create powerful web applications.\n\nEverything explained in detail in Tamil Language.\n\nTechnologies used for full stack development:\n\nFrontEnd \n- HTML\n- CSS\n- JavaScript\n- React\n- Angular\n- Vue\nBackend \n- Express.js\n- Ruby on Rails\n- Python\n- Java\n- Node Js\n- PHP\nDatabases\n- MySQL\n- MongoDB\n- PostgreSQL\n- Aws\n\nJoin our 25k+ Instagram Community\n\nhttps://instagram.com/errormakesclever?igshid=YmMyMTA2M2Y=', 'Published_Date': '2023-05-01T04:30:01Z', 'Duration': 'PT4M22S', 'Views': '172353', 'Likes': '11036', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '2baFLrjuW8s', 'Title': 'Cloud Computing in 30 seconds. Clear definition about cloud in tamil.', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/2baFLrjuW8s/default.jpg', 'Description': '', 'Published_Date': '2023-04-30T04:35:38Z', 'Duration': 'PT1M1S', 'Views': '343420', 'Likes': '34938', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '50F2ysbYLfI', 'Title': 'How to move from one company to another ?? Here is a tip for you to switch companies. #jobswitch', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/50F2ysbYLfI/default.jpg', 'Description': '', 'Published_Date': '2023-04-27T12:30:05Z', 'Duration': 'PT39S', 'Views': '36159', 'Likes': '4398', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'ZpyJe4_xVVA', 'Title': '"Unleashing the Power of Web Development in 30 Seconds! 💻🌐 Exploring HTML, CSS and JS.', 'Tags': ['Html', 'Css', 'JavaScript', 'web', 'web development', 'web development in 30 sec'], 'Thumbnail': 'https://i.ytimg.com/vi/ZpyJe4_xVVA/default.jpg', 'Description': "In this 30-second video, I give a quick overview of web development, covering the basics of HTML, CSS, and JavaScript, as well as a brief mention of backend development. I explain how HTML provides the structure of a webpage, while CSS is used for styling and design, and JavaScript adds interactivity and dynamic behavior. Additionally, I touch on the importance of backend development in creating a fully functional website, which involves building and managing the server-side code and databases that power web applications. Whether you're a beginner or looking to refresh your knowledge, this video provides a concise introduction to the fundamentals of web development.", 'Published_Date': '2023-04-26T12:30:23Z', 'Duration': 'PT1M1S', 'Views': '218533', 'Likes': '30321', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': '7tTB8IaHASc', 'Title': 'TCS NQT ALERT ‼️', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/7tTB8IaHASc/default.jpg', 'Description': '', 'Published_Date': '2023-04-19T12:47:39Z', 'Duration': 'PT33S', 'Views': '24469', 'Likes': '1961', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'ONDDWzXHW28', 'Title': 'Interview Tip for freshers!!', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/ONDDWzXHW28/default.jpg', 'Description': '', 'Published_Date': '2023-04-19T09:43:53Z', 'Duration': 'PT37S', 'Views': '122734', 'Likes': '16465', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'oBBW3fnGejc', 'Title': 'Freshers Try this Hack 💥 #career #careerdevelopment #freshersguide #tips', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/oBBW3fnGejc/default.jpg', 'Description': '', 'Published_Date': '2023-04-17T12:45:19Z', 'Duration': 'PT35S', 'Views': '18706', 'Likes': '2281', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'Krzg0YlFHMs', 'Title': 'On an average Full Stack developer make 6 - 8LPA. The complete web development bootcamp from @udemy.', 'Tags': ['Full stack development', 'Course', 'scam', 'learn'], 'Thumbnail': 'https://i.ytimg.com/vi/Krzg0YlFHMs/default.jpg', 'Description': 'On an average Full Stack developer make 6 - 8LPA. The complete web development bootcamp from @udemy is everything you need to start your full stack development career.\nCourse Link in Bio!!\n#fullstackdeveloper #webdevelopment #udemy #course', 'Published_Date': '2023-04-16T13:48:51Z', 'Duration': 'PT36S', 'Views': '30787', 'Likes': '4099', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'tP8Ku1cjRp4', 'Title': 'Use this linkedin Tip in your Job Hunt 💥 #linkedin #careerguide #career #job #errormakesclever', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/tP8Ku1cjRp4/default.jpg', 'Description': '', 'Published_Date': '2023-04-15T12:30:29Z', 'Duration': 'PT36S', 'Views': '11148', 'Likes': '879', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'Q_mugOseqCc', 'Title': 'Here are the top 4 websites to apply for an internship. #career # students #internship #job at', 'Tags': ['Career', 'Growth', 'education', 'rich', 'money', 'motivation', 'webdevelopment', 'programming', 'cloud', 'student', 'c++', 'java', 'Ai', 'machine learning'], 'Thumbnail': 'https://i.ytimg.com/vi/Q_mugOseqCc/default.jpg', 'Description': '🤞Here are the top 4 websites to apply for an internship. Only less amount of students consider doing internships, those students are definitely getting placed with higher salary when they graduate. Internships are the best place where you can start your career 📈.\nApply Now !!! \n\n#internship #internshipoffer #student #fresher #placement #career #education #tips #webdevelopment #programming #fullstackdeveloper #cloud #computer #engineer #learning', 'Published_Date': '2023-04-14T12:30:24Z', 'Duration': 'PT36S', 'Views': '212295', 'Likes': '29593', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}
# {'Channel_Name': 'Error Makes Clever Academy', 'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A', 'Video_Id': 'oubMNuKC8KA', 'Title': 'Top 5 Job Search Portal for freshers ! #joboffer #career #job #linkedin', 'Tags': None, 'Thumbnail': 'https://i.ytimg.com/vi/oubMNuKC8KA/default.jpg', 'Description': 'Here are the top 5 job for search platforms:\n1. Naukri.com - This is one of the oldest and most popular job search platforms in India, with millions of registered job seekers and companies.\n2. Monster India - This platform offers a wide range of job opportunities across various sectors, including IT, finance, marketing, and others.\n3. Indeed - Indeed is a global platform that has a strong presence in India, offering a wide range of largecorporations.\n4. Linkedin - Linkedin is a powerful networking platform that also offers a job search feature, where job seekers can connect with recruiters and employers.\n5. Shine - Shine.com is a leading job search platform in India that offers job\nopportunities across various industries and job roles.\n#success #motivation #inspiration #love #motivationalquotes #life #entrepreneur #mindset #lifestyle #believe #positivevibes #happiness #instagood #instagram #selflove #inspirationalquotes #webdevelopment #webdesign #webdeveloper #html #website #digitalmarketing #coding #programming #javascript #jobsearch #freejob #parttimejob #joboffer', 'Published_Date': '2023-04-12T05:52:54Z', 'Duration': 'PT44S', 'Views': '96005', 'Likes': '13767', 'Comments': None, 'Favorite_Count': '0', 'Definition': 'hd', 'Caption_Status': 'false'}

# %%
video_details=get_video_info(Video_Ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'YJsqKbqgpEY',
#   'Title': 'CSS Media Queries Explained in Tamil | Responsive Web Development Tutorial',
#   'Tags': ['css',
#    'media',
#    'queries',
#    'webdevelopment',
#    'tamil',
#    'emc',
#    'errormakesclever'],
#   'Thumbnail': 'https://i.ytimg.com/vi/YJsqKbqgpEY/default.jpg',
#   'Description': 'Explore the world of CSS Media Queries in Tamil! 💻💡 Learn how to create dynamic web layouts and understand the nuances of web development in Tamil. This tutorial is your gateway to mastering web design concepts in the Tamil language. 🎥🔥 #CSS #MediaQueries #ResponsiveDesign #WebDevelopmentTutorial #TamilTutorial #emc #errormakesclever\n\nErrorMakesClever Instagram Link 👇👇👇\n https://www.instagram.com/errormakesclever\n\nErrorMakesClever Youtube Link 👇👇👇\nhttps://www.youtube.com/@ErrorMakesClever\n\nErrorMakesClever Whatsapp Channel Link 👇👇👇\nhttps://www.whatsapp.com/channel/0029VaARpx2F1YlQunv38L1Z',
#   'Published_Date': '2024-01-11T12:30:18Z',
#   'Duration': 'PT24M26S',
#   'Views': '12532',
#   'Likes': '520',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'x3dQsMkJgDg',
#   'Title': 'what is UI vs UX design | Explained for beginners | Roadmap and Resources in Tamil',
#   'Tags': ['ui',
#    'ux',
#    'basics',
#    'explained',
#    'tamil',
#    'emc',
#    'errormakesclever'],
#   'Thumbnail': 'https://i.ytimg.com/vi/x3dQsMkJgDg/default.jpg',
#   'Description': '🌐 Explore the basics of UI/UX design in our latest video, all explained in Tamil! Understand the foundations of UI/UX effortlessly with engaging narratives.\n\n⏰ Time Stamps:\n00:00 Introduction\n00:18 What is UI/UX?\n01:45 Freshers Salary\n02:24 UI/UX Tools\n04:16 Figma AI\n04:45 UI/UX Resources\n05:03 UI/UX Portfolio\n\nDiscover how user interface and user experience collaborate to shape seamless digital experiences! 🎨🚀 #UIDesign #UXExplained #DigitalExperience #TamilTutorial #emc #errormakesclever\n\nErrorMakesClever Instagram Link 👇👇👇\n https://www.instagram.com/errormakesclever\n\nErrorMakesClever Youtube Link 👇👇👇\nhttps://www.youtube.com/@ErrorMakesClever\n\nErrorMakesClever Whatsapp Channel Link 👇👇👇\nhttps://www.whatsapp.com/channel/0029VaARpx2F1YlQunv38L1Z',
#   'Published_Date': '2024-01-09T12:30:39Z',
#   'Duration': 'PT6M40S',
#   'Views': '38470',
#   'Likes': '2798',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'QaoKoeMYvoY',
#   'Title': '🔍 LinkedIn Job Search Hack: Pro Tips for Landing Your Dream Job!💼 #shorts #linkedin #jobsearch #emc',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/QaoKoeMYvoY/default.jpg',
#   'Description': 'Use this Quick Short LinkedIn Tip During your Job Search💼🌐 #LinkedInTips #JobSearch #shorts',
#   'Published_Date': '2024-01-09T12:30:14Z',
#   'Duration': 'PT30S',
#   'Views': '84971',
#   'Likes': '8501',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'jnfyH1k2c38',
#   'Title': 'CSS Positioning Made Simple: A Beginner-Friendly Tutorial 🎨✨ | Tamil | EMC',
#   'Tags': ['css',
#    'positioning',
#    'tamil',
#    'tutorial',
#    'beginner',
#    'emc',
#    'errormakesclever',
#    'simple'],
#   'Thumbnail': 'https://i.ytimg.com/vi/jnfyH1k2c38/default.jpg',
#   'Description': '🚀 Master CSS Positioning in Tamil!🖥️✨ Explore essential techniques for web development, from absolute to relative positioning. 💻 Elevate your CSS skills and create visually stunning websites effortlessly. 🌐 Watch now to level up your web design game! 🔥 #css #positioning  #webdevelopment  #tamiltutorial  #emc #errormakesclever\n\nErrorMakesClever Instagram Link 👇👇👇\n https://www.instagram.com/errormakesclever\n\nErrorMakesClever Youtube Link 👇👇👇\nhttps://www.youtube.com/@ErrorMakesClever\n\nErrorMakesClever Whatsapp Channel Link 👇👇👇\nhttps://www.whatsapp.com/channel/0029VaARpx2F1YlQunv38L1Z',
#   'Published_Date': '2024-01-07T12:30:23Z',
#   'Duration': 'PT14M3S',
#   'Views': '19130',
#   'Likes': '975',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'cfCe3wNXtlE',
#   'Title': '🌐 Free Portfolio Templates for Stunning Resumes!! 📄 #shorts #portfolio #resume #templates #emc',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/cfCe3wNXtlE/default.jpg',
#   'Description': '🎨 Elevate your resume game with free portfolio templates! 🚀 Dive into our YouTube Shorts for a quick guide to top websites offering stunning designs. Craft a standout resume effortlessly! 💼✨ #PortfolioTemplates #ResumeDesign #Shorts',
#   'Published_Date': '2024-01-07T12:30:20Z',
#   'Duration': 'PT22S',
#   'Views': '125615',
#   'Likes': '15100',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'L-PxA7xa6UA',
#   'Title': 'High-Paying Jobs💼💸 2024 🌟: Your Road to Prosperity!',
#   'Tags': ['2024', 'highpaying', 'skills', 'jobs', 'emc', 'errormakesclever'],
#   'Thumbnail': 'https://i.ytimg.com/vi/L-PxA7xa6UA/default.jpg',
#   'Description': 'Explore the best-paying jobs of 2024 for a successful future!🌟Discover rewarding careers that bring prosperity and fulfillment. Start your journey now! 🚀💰 #shorts #highpayingskills #2024jobs #careersuccess #emc',
#   'Published_Date': '2024-01-05T12:30:11Z',
#   'Duration': 'PT1M',
#   'Views': '266690',
#   'Likes': '19550',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'J16CecpALAk',
#   'Title': 'Worried about getting job in 2024? #shorts  #nojob #highpayingskills #emc',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/J16CecpALAk/default.jpg',
#   'Description': '😟 Worried about getting a job in 2024? Watch this video where I provide insights about the job market. 🌐 Learn high-paying skills in the next 6 months and stand out from the crowd! 💼 #jobsearch #careeradvice',
#   'Published_Date': '2024-01-03T12:30:14Z',
#   'Duration': 'PT46S',
#   'Views': '155088',
#   'Likes': '14968',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '7dSJubxFWv0',
#   'Title': 'Front End Web Development Tutorial for Beginner | In Tamil | Final Project',
#   'Tags': ['errormakesclever',
#    'emc',
#    'frontend',
#    'tutorial',
#    'tamil',
#    'beginners',
#    'coding',
#    'project',
#    'webdevelopment'],
#   'Thumbnail': 'https://i.ytimg.com/vi/7dSJubxFWv0/default.jpg',
#   'Description': '🚀 Master Front-End Web Development with this Comprehensive Tutorial in Tamil! 🌐\n\n🕒 Timestamps:\n00:00 Introduction\n00:18 HTML Basics\n01:07:37 CSS Fundamentals\n02:11:28 CSS Positioning\n02:25:36 CSS Flexbox\n02:55:19 Media Queries\n03:19:42 JavaScript Essentials\n07:54:07 E-Commerce Project Showcase\n\n📚 Dive into the world of web development as we cover everything from HTML and CSS to advanced techniques like Flexbox and Media Queries. The tutorial is designed for beginners and tailored for Tamil-speaking audiences.\n\n💡 Highlights:\n- Learn HTML from scratch\n- Master CSS fundamentals and positioning\n- Explore the power of CSS Flexbox\n- Implement responsive design with Media Queries\n- Grasp the basics of JavaScript\n- Cap it off with a hands-on E-Commerce Project\n\n👨\u200d💻 Perfect for beginners and those looking to enhance their skills. Subscribe for regular updates and empower yourself to create stunning websites! 💻✨ #WebDevelopment #FrontEndDevelopment #TamilTutorial #CodingForBeginners',
#   'Published_Date': '2024-01-03T12:30:03Z',
#   'Duration': 'PT8H50M4S',
#   'Views': '145655',
#   'Likes': '5401',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'djbJjGp2tc8',
#   'Title': '2023 = Learning!',
#   'Tags': ['Emc', 'Error makes clever', 'success'],
#   'Thumbnail': 'https://i.ytimg.com/vi/djbJjGp2tc8/default.jpg',
#   'Description': 'We would like to hear from you 😊, Fill the below form \n\nhttps://forms.gle/VRdKySU1nc5J29A16',
#   'Published_Date': '2023-12-26T12:30:18Z',
#   'Duration': 'PT58S',
#   'Views': '299733',
#   'Likes': '27397',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '1h35ad0yn-w',
#   'Title': 'Don’t miss this hack ! Try it. #linkedin #trick',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/1h35ad0yn-w/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-23T10:18:26Z',
#   'Duration': 'PT28S',
#   'Views': '65677',
#   'Likes': '6954',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '_pqX3eIOQ9k',
#   'Title': 'DAY-14 LINUX:operating system is the software that directly manages a system hardware and resources',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/_pqX3eIOQ9k/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-20T12:34:11Z',
#   'Duration': 'PT37S',
#   'Views': '65822',
#   'Likes': '7018',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'kkn0pnLqaco',
#   'Title': 'DAY-13 WWW: A system of interconnected public webpages accessible through the Internet#emc#tech#www',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/kkn0pnLqaco/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-19T13:14:04Z',
#   'Duration': 'PT59S',
#   'Views': '30806',
#   'Likes': '2997',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'hVWhsHOQbXM',
#   'Title': 'Learn CSS Flexbox with Project | Flex Tutorial | Web Development Project | EMC | In Tamil',
#   'Tags': ['css',
#    'flexbox',
#    'css layout',
#    'css in tamil',
#    'learn css',
#    'flexbox tutorial',
#    'tamil tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/hVWhsHOQbXM/default.jpg',
#   'Description': "Next Full Stack Web Development Batch Registration Link:\nhttps://bitly.ws/YAsk\n\nFor course related queries contact us:\n📞 8270496560\n✉️ errormakesclever@gmail.com\n\nFollow us on LinkedIn to get more updates on Tech:\nhttps://www.linkedin.com/company/errormakesclever/\n\nJoin 500k+ Instagram Community:\nhttps://www.instagram.com/errormakesclever/\n\n🚀 Mastering CSS Flexbox Tutorial: Dive into the world of flexible layouts with our comprehensive guide to CSS Flexbox! In this tutorial, we'll demystify Flexbox, the powerful layout model that makes designing responsive and dynamic web pages a breeze. Learn how to create complex and adaptive layouts with ease, as we cover Flex containers, items, alignment, ordering, and more. Whether you're a beginner or looking to enhance your front-end skills, this tutorial provides clear explanations, practical examples, and tips to elevate your CSS game. Watch, code along, and unlock the potential of Flexbox for creating modern, responsive web designs! 💻🎨 #CSSFlexbox #WebDesign #CSSLayout",
#   'Published_Date': '2023-12-16T05:51:57Z',
#   'Duration': 'PT30M',
#   'Views': '33682',
#   'Likes': '1255',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'qbl7tOaQF20',
#   'Title': 'Websites for Project Ideas, Make use of it ! #shorts #emc',
#   'Tags': ['website for project', 'project ideas', 'new project'],
#   'Thumbnail': 'https://i.ytimg.com/vi/qbl7tOaQF20/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-13T12:30:25Z',
#   'Duration': 'PT29S',
#   'Views': '107909',
#   'Likes': '9234',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'JHHBOLBt1JI',
#   'Title': 'ATS Resume Tool is here 👆👆 #resume #ats',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/JHHBOLBt1JI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-12T13:46:08Z',
#   'Duration': 'PT27S',
#   'Views': '200054',
#   'Likes': '19219',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '6ImT0CuJVX4',
#   'Title': 'A Journey from Non-IT to IT Industry 🚀| Zero Coding Experience | EMC Academy Student Podcast',
#   'Tags': ['emc',
#    'errormakesclever',
#    'review',
#    'emc review',
#    'full stack web development',
#    'tamil emc',
#    'tamil course',
#    'non it to it',
#    'non technical',
#    'zero coding',
#    'non technical to technical',
#    'placed',
#    'lpa',
#    'highest package',
#    'emc student'],
#   'Thumbnail': 'https://i.ytimg.com/vi/6ImT0CuJVX4/default.jpg',
#   'Description': "Next Full Stack Web Development Batch Registration Link:\nhttps://bitly.ws/YAsk\n\nFor course related queries contact us:\n📞 8270496560\n✉️ errormakesclever@gmail.com\n\nFollow us on LinkedIn to get more updates on Tech:\nhttps://www.linkedin.com/company/errormakesclever/\n\nJoin 500k+ Instagram Community:\nhttps://www.instagram.com/errormakesclever/\n\nMustafa LinkedIn Id:\nhttps://www.linkedin.com/in/musthafa2324\n\nDive into our latest podcast episode, where we share the incredible journey of someone who went from knowing nothing about IT to landing a job in the industry. This person, who studied at the Error Makes Clever Academy, talks about their experience in a Full Stack Web Development course.\n\nIn this podcast, we explore how an average student with a BA in Religious Studies transformed their career by learning to code with us. You'll hear about the challenges they faced, how they built a strong resume, and the LinkedIn hacks that helped them stand out in the job market.\n\nDiscover how Error Makes Clever Academy's unique approach helps students, even those without a technical background, secure placements in the IT field. We discuss the importance of developing skills, effective networking, and the commitment to continuous learning.\n\nWhether you're considering a career change or just want to boost your skills, this podcast is a valuable guide. Join us as we talk about non-technical beginnings, the journey from zero coding to a confident IT professional, and how you can take the first steps toward a successful career switch. Don't miss out on insights that could transform your career in the IT industry.",
#   'Published_Date': '2023-12-12T04:44:56Z',
#   'Duration': 'PT23M37S',
#   'Views': '40179',
#   'Likes': '1861',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '1Z4itB15U_s',
#   'Title': 'DAY 12 : Data structures - a specific way of organizing data in a specialized format on a computer',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/1Z4itB15U_s/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-12-04T03:32:44Z',
#   'Duration': 'PT44S',
#   'Views': '153699',
#   'Likes': '8740',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'iBEAquFXHWg',
#   'Title': 'DAY 11 -Docker:A open platform for developing, Shipping and Running Applications #shorts #emc #tech',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/iBEAquFXHWg/default.jpg',
#   'Description': 'DAY 11 -Docker:A open platform for developing, Shipping and Running Applications #shorts #emc #tech',
#   'Published_Date': '2023-12-01T15:24:34Z',
#   'Duration': 'PT47S',
#   'Views': '113620',
#   'Likes': '10414',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '9SwNLkRmg7Y',
#   'Title': 'DAY 10 - API : Obtaining data from another application is done through something#shorts #emc #tech',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/9SwNLkRmg7Y/default.jpg',
#   'Description': 'DAY 10 - API : Obtaining data from another application is done through something is API',
#   'Published_Date': '2023-11-28T12:30:05Z',
#   'Duration': 'PT49S',
#   'Views': '46016',
#   'Likes': '4139',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '9cQaOXgi8XQ',
#   'Title': 'DAY 9: "LLM" - Explore Language Model in a snap! #emc #tech #llm #ai',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/9cQaOXgi8XQ/default.jpg',
#   'Description': 'DAY 9: "LLM" - Explore Language Model in a snap!',
#   'Published_Date': '2023-11-27T12:30:04Z',
#   'Duration': 'PT57S',
#   'Views': '85223',
#   'Likes': '7917',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'ytQQ1TXz-CI',
#   'Title': 'DAY 8-Dive into the world of data Engineering-where insights meet innovation #shorts #emc #tech',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ytQQ1TXz-CI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-11-23T12:31:23Z',
#   'Duration': 'PT44S',
#   'Views': '59022',
#   'Likes': '5582',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 't22s6omEr4M',
#   'Title': 'DAY 7 :virtualization -Learn the efficiency of virtual environments #shorts #emc #tech',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/t22s6omEr4M/default.jpg',
#   'Description': 'DAY 7 :VIRTUALIZATION',
#   'Published_Date': '2023-11-22T12:30:35Z',
#   'Duration': 'PT48S',
#   'Views': '53570',
#   'Likes': '5218',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'FZmR_m0KuC8',
#   'Title': 'Day 6 : Battle of Minds: Machine learning Vs Deep learning in 100 bytes #shorts #EMC #tech',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/FZmR_m0KuC8/default.jpg',
#   'Description': 'Day 6 : Battle of Minds: Machine learning Vs Deep learning',
#   'Published_Date': '2023-11-20T12:30:12Z',
#   'Duration': 'PT45S',
#   'Views': '63322',
#   'Likes': '6186',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'Xd0uGWDrVXI',
#   'Title': 'DAY 5 : IP Address - Devices communicate across the vast landscape of world wide web #EMC #shorts',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Xd0uGWDrVXI/default.jpg',
#   'Description': 'DAY 5 : IP Address Explanation',
#   'Published_Date': '2023-11-18T12:48:02Z',
#   'Duration': 'PT59S',
#   'Views': '128710',
#   'Likes': '8828',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'CsnEBjbdO7g',
#   'Title': 'DAY 4- BIG DATA : From bytes to breakthroughs,a journey into the heart of innovation.#EMC #shorts',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/CsnEBjbdO7g/default.jpg',
#   'Description': 'DAY 4- Explaining BIG DATA',
#   'Published_Date': '2023-11-17T12:30:11Z',
#   'Duration': 'PT53S',
#   'Views': '43595',
#   'Likes': '4199',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'sJSucvrMp80',
#   'Title': "Day 3 : Navigating the web's secret passages with the cloak of VPN invisibility #shorts #vpn #EMC",
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/sJSucvrMp80/default.jpg',
#   'Description': 'Day 3/30 - Explaining VPN',
#   'Published_Date': '2023-11-17T04:30:15Z',
#   'Duration': 'PT54S',
#   'Views': '60047',
#   'Likes': '5289',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'gUMbjfuudZ0',
#   'Title': 'Day 2 : RAM : The silent hero fueling your digital adventures! #errormakesclever #tech #shorts',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/gUMbjfuudZ0/default.jpg',
#   'Description': 'Day 2/30 - RAM explanation',
#   'Published_Date': '2023-11-16T12:30:31Z',
#   'Duration': 'PT53S',
#   'Views': '166672',
#   'Likes': '16599',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'xZZrnDtK0qc',
#   'Title': 'Empower your plants with a voice! Watch them thrive and speak their needs! #shorts #iot',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/xZZrnDtK0qc/default.jpg',
#   'Description': 'Bringing my plants into the digital age with IoT magic!',
#   'Published_Date': '2023-11-15T12:30:36Z',
#   'Duration': 'PT50S',
#   'Views': '134149',
#   'Likes': '11643',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '6RmVZ4yRKeE',
#   'Title': 'Full Stack Web Development Course | MERN | 3 Months Course by Error Makes Clever',
#   'Tags': ['full stack',
#    'tamil',
#    'course',
#    '3 months',
#    'learn',
#    'master',
#    'best'],
#   'Thumbnail': 'https://i.ytimg.com/vi/6RmVZ4yRKeE/default.jpg',
#   'Description': "Registration Link: https://bitly.ws/YAsk\nContact: 8270496560 for any queries \n\nUnlock Your Full Stack Potential - Enroll Now at a Special Rate!\nHi there,\nHope this message finds you well!\n\n🚀 Exciting News: Our Full Stack Web Development course is set to kick off on November 6, and we're thrilled to invite you to be a part of it!\n\n🔥 Act Fast - Limited-Time Offer: To celebrate the launch, we're offering an exclusive discounted rate of ₹14,999 instead of the original ₹17,777 for the first 50 registrations! Secure your spot now and dive into the world of Full Stack development without breaking the bank.\n\n🌐 Why Full Stack? Our comprehensive course covers everything from front-end design to back-end functionality, ensuring you gain mastery in every aspect of web development. Whether you're a beginner or looking to level up your skills, our program is designed to empower you with the knowledge and tools needed for success in the dynamic field of Full Stack Web Development.\n\n💡 What's in Store for You?\n- Hands-on learning with industry-relevant projects\n- Expert-led sessions to guide you at every step\n- Access to a lifetime of recorded sessions for continuous learning\n- Full job assistance, from resume building to LinkedIn optimization\n\n🎓 Don't Miss Out: With seats filling up fast, this is your chance to join a vibrant community of learners and professionals. Embrace the opportunity to boost your career with in-demand Full Stack skills.\n\n🚨 Act Now: Register before November 6 to lock in the special rate of ₹14,999 and secure your place in our upcoming Full Stack Web Development class. Time is ticking, and we don't want you to miss out on this fantastic offer!\n\nReady to embark on your Full Stack journey? Click https://bitly.ws/YAsk to enroll now.\n\nSee you in class, where innovation meets development!",
#   'Published_Date': '2023-10-31T04:20:05Z',
#   'Duration': 'PT3M35S',
#   'Views': '72295',
#   'Likes': '2812',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'Omu2WhkoydU',
#   'Title': 'Who is the world first programmer? #adalovelace #worldfirstprogrammer #code',
#   'Tags': ['Ada lovelace', 'programmer', 'charles babbage', 'computer'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Omu2WhkoydU/default.jpg',
#   'Description': 'Who holds the title of the world\'s first programmer? Ada Lovelace earns that distinction, having collaborated with Charles Babbage, widely recognized as the father of computer. Ada\'s pioneering contributions laid the groundwork for the modern computer. Every second Tuesday of October, Ada Lovelace Day celebrates her legacy, inspiring women to pursue science, math, and engineering. Follow for more insightful content like this. 🖥️👩\u200d💻 #AdaLovelace #PioneerOfProgramming #WomenInSTEM #TechInnovation"',
#   'Published_Date': '2023-10-28T14:19:33Z',
#   'Duration': 'PT49S',
#   'Views': '59785',
#   'Likes': '5400',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'eIwJZBzT7fg',
#   'Title': 'Client side rendering Vs Server side rendering explained #web',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/eIwJZBzT7fg/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-18T12:47:09Z',
#   'Duration': 'PT58S',
#   'Views': '48787',
#   'Likes': '4255',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'poo0BXryffI',
#   'Title': 'JavaScript tutorial for Beginners in Tamil | DOM Explained | Mini Project in JavaScript',
#   'Tags': ['javascript',
#    'javascript tutorial for beginners',
#    'javascript in tamil',
#    'tamil programming',
#    'javascript made easy',
#    'build a mini project using javascript',
#    'javascript essentials',
#    'javascript programming'],
#   'Thumbnail': 'https://i.ytimg.com/vi/poo0BXryffI/default.jpg',
#   'Description': "MERN STACK DEVELOPMENT COURSE \npre-registration link: https://forms.gle/91gEAibDD5EVk7aP7\n\nTimestamps:\n\n00:00 - Intro\n00:52 - Course Preview\n01:24 - JavaScript Intro\n02:34 - Variables\n22:12 - Keywords\n23:09 - Comments\n24:35 - Operators\n31:43 - DataTypes\n34:47 - Functions and Exercise\n58:25 - if else and Exercise\n01:18:48 - For Loop\n01:30:40 - Dom Manipulation \n01:43:00 - Dom Events and Exercise\n02:05:55 - Random Numbers \n02:23:10 - DOM Style Manipulation \n02:28:30 - Task1 \n02:33:18 - Task2\n02:41:05 - Task3\n02:42:37 - Task4\n02:50:01 - Task5\n02:56:10 - Todo List\n03:36:10 - Booksky Project\n04:34:35 - End\n\nIn this insightful YouTube video, I delve into the fundamentals of JavaScript, focusing on its Document Object Model (DOM) and basic programming concepts. Join me on a journey through JavaScript's core principles, and discover how to leverage DOM for dynamic web development. Whether you're a beginner or looking to reinforce your programming skills, this tutorial provides a clear and engaging overview of JavaScript essentials, accompanied by practical examples to enhance your understanding. Uncover the power of JavaScript and kickstart your programming journey with confidence! \n\nHappy Learning !",
#   'Published_Date': '2023-10-11T11:08:24Z',
#   'Duration': 'PT4H35M10S',
#   'Views': '368905',
#   'Likes': '9152',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'sSKFx39UUpk',
#   'Title': 'Automate Job Apply process using AI #ai #resume #job',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/sSKFx39UUpk/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-10T14:27:31Z',
#   'Duration': 'PT41S',
#   'Views': '112179',
#   'Likes': '12758',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'l4y5flTC1g4',
#   'Title': 'Explore the opportunities as a wordpress developer 🚀 #wordpress',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/l4y5flTC1g4/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-07T12:51:17Z',
#   'Duration': 'PT29S',
#   'Views': '78603',
#   'Likes': '7750',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'GnOSxrLh3_0',
#   'Title': '#11 Understanding SQL Primary Key | SQL tutorial for beginners | in tamil',
#   'Tags': ['SQL',
#    'Primary Keys',
#    'Database Design',
#    'Data Integrity',
#    'SQL Tutorial',
#    'Database Management',
#    'SQL Tips',
#    'Database Development',
#    'SQL Queries',
#    'SQL Server',
#    'MySQL',
#    'PostgreSQL',
#    'Database Fundamentals',
#    'Data Management',
#    'Programming',
#    'Coding',
#    'Tech Tutorial',
#    'SQL Skills',
#    'SQL Mastery',
#    'SQL Best Practices.'],
#   'Thumbnail': 'https://i.ytimg.com/vi/GnOSxrLh3_0/default.jpg',
#   'Description': "Welcome to our SQL tutorial on Primary Keys! In this video, we'll dive deep into the concept of Primary Keys in SQL databases. Whether you're a beginner looking to learn the fundamentals or an experienced developer seeking a refresher, this tutorial is for you.\n\n🔑 What You'll Learn:\n- What is a Primary Key and why is it essential in database design.\n- How to define a Primary Key in SQL tables.\n- The role of Primary Keys in ensuring data integrity.\n- Practical examples and best practices for using Primary Keys.\n- Common mistakes to avoid when working with Primary Keys.\n\nBy the end of this video, you'll have a solid understanding of SQL Primary Keys and how to implement them effectively in your database projects. Whether you're using MySQL, PostgreSQL, SQL Server, or another SQL database system, the principles covered here will apply.\n\nDon't forget to like, share, and subscribe for more informative SQL tutorials! If you have any questions or topics you'd like us to cover in future videos, please leave them in the comments section below.\n\nThanks for watching, and let's get started on our journey to becoming SQL experts! 🔍📊💡\n\n#SQL #PrimaryKeys #DatabaseDesign #SQLTutorial #DataIntegrity #DatabaseManagement",
#   'Published_Date': '2023-10-06T13:43:38Z',
#   'Duration': 'PT8M34S',
#   'Views': '8774',
#   'Likes': '252',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'tcjcjHX9wcA',
#   'Title': '#10 SQL 25 Practice Questions | DDL, DML, DQL, Group by, Having | SQL Tutorial for beginners | tamil',
#   'Tags': ['SQL',
#    'Database',
#    'DDL',
#    'DQL',
#    'DML',
#    'GROUP BY',
#    'HAVING Clause',
#    'DataQuery',
#    'DataManipulation',
#    'DatabaseSkills',
#    'SQLTutorial',
#    'SQLQuestions',
#    'SQLAnswers',
#    'DatabaseManagement',
#    'SQLTips',
#    'SQLLearning',
#    'SQLMastery',
#    'DataAnalysis',
#    'SQLInterview',
#    'SQLQueries',
#    'SQLBasics',
#    'DatabaseDevelopment',
#    'SQLTraining',
#    'SQLForBeginners',
#    'SQLKnowledge',
#    'SQLExperts'],
#   'Thumbnail': 'https://i.ytimg.com/vi/tcjcjHX9wcA/default.jpg',
#   'Description': "Unlock the power of SQL with our comprehensive guide! In this in-depth video tutorial, we cover 25 fundamental SQL questions and answers that encompass Data Definition Language (DDL), Data Query Language (DQL), Data Manipulation Language (DML), GROUP BY, and the HAVING clause. Whether you're a beginner looking to learn SQL from scratch or an experienced developer looking to sharpen your SQL skills, this video has something for everyone.\n\nHere's what you can expect from this tutorial:\n- **DDL:** Discover how to create, modify, and manage database structures like a pro.\n- **DQL:** Learn the art of querying data with SELECT statements and filtering your results effectively.\n- **DML:** Master the skills needed to insert, update, and delete data while maintaining data integrity.\n- **GROUP BY:** Dive deep into grouping and aggregating data to gain valuable insights.\n- **HAVING Clause:** Explore how to filter grouped data and harness its power for advanced analysis.\n\nEach SQL question is meticulously explained with clear examples and detailed answers, ensuring you understand the core concepts and best practices. Whether you're preparing for an interview, enhancing your database skills, or simply curious about SQL, this video is your one-stop resource.\n\nDon't miss out on this opportunity to become a SQL expert! Hit the play button now and level up your database skills. If you find this video helpful, please like, share, and subscribe for more informative tutorials on SQL and database management.",
#   'Published_Date': '2023-10-05T12:30:28Z',
#   'Duration': 'PT33M13S',
#   'Views': '18464',
#   'Likes': '515',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'e_su8zuTtMo',
#   'Title': 'Tips for youtube learners 🚀💥',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/e_su8zuTtMo/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-10-04T12:30:22Z',
#   'Duration': 'PT32S',
#   'Views': '324994',
#   'Likes': '45696',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '5682golSP5I',
#   'Title': '#9 SQL Having clause Explained | in Tamil | SQL A-Z tutorial series for beginners',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/5682golSP5I/default.jpg',
#   'Description': "In the world of SQL, the `HAVING` clause is a powerful tool that helps us filter and manipulate data in a way that the `WHERE` clause can't quite manage. While the `WHERE` clause filters rows based on conditions applied to individual records, the `HAVING` clause comes into play when we want to filter the results of aggregated data, typically from `GROUP BY` operations.\n\nThink of it like this: the `WHERE` clause is your gatekeeper for individual rows, deciding which rows make it into the result set. In contrast, the `HAVING` clause acts as a bouncer for aggregated data, letting you control which groups of data get to join the party in your final result set.\n\nHere's what you'll learn in this video:\n\n1. **The Basics**: I'll start by explaining the basic syntax of the `HAVING` clause and how it's used in conjunction with the `GROUP BY` clause.\n\n2. **Aggregation**: We'll explore the power of aggregation functions like `SUM`, `COUNT`, `AVG`, and `MAX`, and see how they're often paired with `HAVING` to filter summarized data.\n\n3. **Examples**: I'll provide real-world examples to illustrate when and why you'd want to use `HAVING`, such as finding customers who've made more than a certain number of purchases or products with a certain sales threshold.\n\n4. **Comparison with WHERE**: We'll draw a clear distinction between the `HAVING` and `WHERE` clauses, so you'll know exactly when to use each.\n\nBy the end of this video, you'll have a solid grasp of how the `HAVING` clause is your go-to tool for filtering and shaping summarized data in SQL. It's a must-know for anyone working with databases, especially when dealing with reporting and analytics. So, if you're ready to level up your SQL skills, hit that play button and let's dive into the world of SQL's `HAVING` clause!\n\nDon't forget to like this video, subscribe to our channel, and hit the notification bell to stay updated with more database tutorials and tips. Let's get started! 🚀",
#   'Published_Date': '2023-09-28T06:32:11Z',
#   'Duration': 'PT4M48S',
#   'Views': '13435',
#   'Likes': '299',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'Y7Kqbc0sDGI',
#   'Title': '#8 SQL Group by and Order by | SQL A-Z Tutorial Series | for beginners in tamil | EMC',
#   'Tags': ['SQL',
#    'Database Management',
#    'Data Analysis',
#    'SQL Tutorial',
#    'Group By',
#    'Order By',
#    'SQL Examples',
#    'SQL Queries',
#    'Database',
#    'Sorting Data',
#    'Data Organization',
#    'SQL Basics',
#    'Query Optimization',
#    'SQL Commands',
#    'Data Sorting',
#    'SQL Grouping',
#    'SQL Training',
#    'Data Manipulation',
#    'SQL Tips',
#    'SQL Tricks'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Y7Kqbc0sDGI/default.jpg',
#   'Description': '🎥 Explore SQL - Group By and Order By with Examples 📊\n\nWelcome to our SQL tutorial series! In this video, we\'ll dive into the powerful SQL commands "GROUP BY" and "ORDER BY" with real-world examples. \n\nIn the world of databases, understanding how to group and order your data is crucial, and we\'ve got you covered. Whether you\'re a beginner or looking to refresh your SQL skills, this tutorial is for you.\n\n🔍 What You\'ll Learn:\n- How to group your data based on specific criteria.\n- Sorting your results in ascending and descending order.\n- Practical examples to solidify your understanding.\n- Tips and tricks for optimizing your SQL queries.\n\n🚀 Get ready to unlock the full potential of SQL for data analysis and database management.\n\n👍 Don\'t forget to like, share, and subscribe to our channel for more SQL tutorials and data-related content!\n\n💬 Got questions or suggestions? Drop them in the comments below, and we\'ll be there to assist you.\n\n#SQL #DatabaseManagement #DataAnalysis #SQLTutorial #GroupBy #OrderBy #SQLExamples',
#   'Published_Date': '2023-09-25T13:24:05Z',
#   'Duration': 'PT25M27S',
#   'Views': '18854',
#   'Likes': '464',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '4igiQuJaifU',
#   'Title': 'Focus on one programming language 🙌 #programming #coding',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/4igiQuJaifU/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-09-23T14:39:26Z',
#   'Duration': 'PT40S',
#   'Views': '808878',
#   'Likes': '66141',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 't8VY9kaM_t0',
#   'Title': 'Build your LinkedIn connections 🚀🙌',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/t8VY9kaM_t0/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-09-21T14:41:04Z',
#   'Duration': 'PT39S',
#   'Views': '250953',
#   'Likes': '24126',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '-FfEiNu2ar8',
#   'Title': '#7 Aggregate Functions in SQL | SQL Tutorial for Beginners Series | SQL in Tamil | EMC',
#   'Tags': ['SQL',
#    'AggregateFunctions',
#    'DataAnalysis',
#    'SQLTutorial',
#    'DatabaseManagement',
#    'TechSkills',
#    'SQLTips',
#    'DataSummarization',
#    'SQLFunctions',
#    'SQLQueries',
#    'DatabaseAnalysis',
#    'SQLCalculations',
#    'DatabaseInsights',
#    'SQLLearning',
#    'DatabaseDevelopment',
#    'SQLMastery',
#    'DataAnalytics',
#    'SQLQuerying',
#    'DatabaseSkills',
#    'SQLExamples'],
#   'Thumbnail': 'https://i.ytimg.com/vi/-FfEiNu2ar8/default.jpg',
#   'Description': "Discover the power of SQL Aggregate Functions in our latest YouTube video! 📊\n\n🚀 In this tutorial, we delve into the world of SQL and explore five fundamental aggregate functions: COUNT, SUM, AVG, MAX, and MIN.\n\n💡 Uncover the secrets of data summarization, calculation, and analysis as we break down each function with practical examples and explanations.\n\n🔍 Learn how to harness the full potential of these functions to extract meaningful insights from your database and streamline your data-related tasks.\n\n📋 Whether you're a data enthusiast, analyst, or database developer, this video is your key to unlocking advanced SQL capabilities.\n\n📲 Don't forget to like, subscribe, and hit that notification bell to stay updated with more SQL tutorials and tips! 💬📚\n\n#SQL #AggregateFunctions #DataAnalysis #SQLTutorial #DatabaseManagement #TechSkills #SQLTips\n\n[Insert your social media links and a call to action here]",
#   'Published_Date': '2023-09-21T14:39:28Z',
#   'Duration': 'PT8M18S',
#   'Views': '18910',
#   'Likes': '403',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'uhWu8JBRIa0',
#   'Title': '#6 SQL Practice Questions | SQL A-Z Tutorial Series | Sql for beginners full tutorial in tamil',
#   'Tags': ['SQL Practice',
#    'SQL Questions',
#    'SQL Tutorial',
#    'DDL Commands',
#    'DML Commands',
#    'Database Management',
#    'SQL Queries',
#    'Learn SQL',
#    'SQL Fundamentals',
#    'SQL Basics',
#    'SQL Skills',
#    'Database Design',
#    'SQL Training',
#    'SQL Tips',
#    'SQL Simplified',
#    'SQL Made Easy',
#    'SQL Mastery',
#    'Database Solutions',
#    'SQL Problem Solving',
#    'SQL Help',
#    'SQL Study',
#    'SQL Test',
#    'SQL Quiz',
#    'SQL Lessons',
#    'Database Practice',
#    'SQL Demystified'],
#   'Thumbnail': 'https://i.ytimg.com/vi/uhWu8JBRIa0/default.jpg',
#   'Description': "Check out our latest YouTube video where we tackle 13 SQL practice questions, breaking down each one with a clear and concise explanation. 📚\n\n🔍 Dive into the world of SQL as we unravel the power of DDL (Data Definition Language) and DML (Data Manipulation Language) commands through simple yet essential questions.\n\n💡 Enhance your SQL skills, master database management, and understand how to create, modify, and query data effectively.\n\n🚀 Whether you're a beginner looking for foundational SQL knowledge or seeking a quick refresher, this video has got you covered!\n\n📋 Don't forget to like, subscribe, and hit that notification bell to stay updated with more SQL tutorials and practice questions! 📲💬\n\n#SQLPractice #DDLCommands #DMLCommands #SQLQueries #DatabaseManagement #SQLTutorial #TechEducation\n\n[Insert your social media links and a call to action here]",
#   'Published_Date': '2023-09-19T12:37:45Z',
#   'Duration': 'PT18M6S',
#   'Views': '29884',
#   'Likes': '632',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '_m7ap8EvAEM',
#   'Title': 'Stop complaining and Start Doing 🚀💥 #money',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/_m7ap8EvAEM/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-09-18T12:30:14Z',
#   'Duration': 'PT40S',
#   'Views': '132189',
#   'Likes': '15751',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'xPhImdnkJyo',
#   'Title': '#5 DML Commands in SQL | Insert, Update, Delete, Select | sql tutorial for beginners in tamil',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/xPhImdnkJyo/default.jpg',
#   'Description': "Unlock the power of SQL Data Manipulation Language (DML) commands and SELECT statements with our comprehensive YouTube tutorial! 🚀\n\n🔥 Dive into the world of SQL as we cover the essential DML commands: INSERT, UPDATE, DELETE, and SELECT. Learn how to manipulate data and query your database like a pro.\n\n💡 Discover the art of retrieving specific information from your database with the SELECT command. We'll walk you through various querying techniques and practical examples.\n\n🛠️ Get hands-on experience with real-world scenarios, and master the skills you need for effective data management and analysis.\n\n👩\u200d💻 Whether you're a beginner looking to start your SQL journey or an experienced user seeking to refine your skills, this tutorial has something for everyone.\n\n📋 Don't forget to like, subscribe, and hit that notification bell to stay updated with more SQL tutorials and tips! 📲💬\n\n#SQL #DataManipulation #SELECTCommand #DMLCommands #DatabaseQuery #SQLTutorial #TechSkills",
#   'Published_Date': '2023-09-18T12:20:19Z',
#   'Duration': 'PT16M24S',
#   'Views': '40060',
#   'Likes': '878',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'zHjpQnmA9sg',
#   'Title': '#4 DDL Commands | A Short & Crisp Tutorial with Examples | In Tamil | SQL | Error Makes Clever',
#   'Tags': ['SQL',
#    'DatabaseManagement',
#    'DDLCommands',
#    'Tutorial',
#    'TechTips',
#    'SQLBasics',
#    'DatabaseDesign',
#    'SQLTutorial',
#    'LearnSQL',
#    'DataManagement',
#    'DatabaseAdmin',
#    'StructuredQueryLanguage',
#    'DatabaseStructure',
#    'DatabaseDevelopment',
#    'SQLCommands',
#    'SQLSyntax',
#    'SQLExamples',
#    'DatabaseTutorial',
#    'CodingTutorial',
#    'DatabaseSchema',
#    'DatabaseTables',
#    'SQLPro',
#    'TechLearning',
#    'DataManipulation',
#    'DatabaseFundamentals',
#    'DDLSQL',
#    'DatabaseSkills',
#    'DatabaseCreation',
#    'SQLQueries',
#    'TechEducation'],
#   'Thumbnail': 'https://i.ytimg.com/vi/zHjpQnmA9sg/default.jpg',
#   'Description': "In this concise YouTube tutorial, dive into the world of Database Definition Language (DDL) commands and become a SQL pro! 💻\n\n🔍 Explore the fundamental DDL commands: CREATE, ALTER, and DROP, and discover how they shape the structure of your database.\n\n🚀 Follow along with real-world examples and step-by-step explanations that demystify DDL commands.\n\n📋 Learn how to create tables, modify their structure, and gracefully remove them using SQL DDL commands.\n\n🎯 Whether you're a beginner or a seasoned SQL user, this tutorial will help you sharpen your skills and harness the power of DDL commands for database management.\n\n💡 Don't forget to like, subscribe, and hit that notification bell to stay updated with more tech tutorials and tips! 📲💬\n\n#SQL #DatabaseManagement #DDLCommands #Tutorial #techtips \n\nJoin our instagram community\nhttps://www.instagram.com/errormakesclever/",
#   'Published_Date': '2023-09-14T06:49:19Z',
#   'Duration': 'PT13M6S',
#   'Views': '59062',
#   'Likes': '1405',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
# ...
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'Rtmgt2Qfqr4',
#   'Title': '#02 Variables and DataTypes Explained 🔋| In Tamil | Python Tutorial Series 🚀| EMC Academy',
#   'Tags': ['Python',
#    'Python in tamil',
#    'python tutorial in tamil',
#    'Python variables and datatypes',
#    'how to code',
#    'variables and datatypes in python',
#    'variables explained',
#    'datatypes explained',
#    'python tutorial series',
#    'emc academy',
#    'errormakescleveracademy'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Rtmgt2Qfqr4/default.jpg',
#   'Description': "In this particular video, we'll be exploring the basics of Python programming language, specifically the concepts of variables, data types, and operators.\n\nPython is a high-level, interpreted programming language that is widely used in many different fields, including web development, data science, and machine learning. Understanding the fundamentals of Python is essential for anyone looking to pursue a career in these areas.\n\nWe'll start by discussing variables, which are used to store values in Python. We'll cover how to declare and initialize variables, as well as how to assign and reassign values to them.\n\nNext, we'll move on to data types, which are used to define the type of data that a variable can hold. Python has several built-in data types, including integers, floats, strings, and booleans. We'll explore each of these in detail and discuss how to convert between them.\n\nFinally, we'll discuss operators, which are used to perform operations on variables and data. Python has several different types of operators, including arithmetic operators, comparison operators, and logical operators. We'll demonstrate how each of these operators works and provide examples of how to use them in your own code.\n\nBy the end of this video, you'll have a solid understanding of Python variables, data types, and operators, and be well on your way to becoming a proficient Python programmer.\n\nPython in Tamil \n\nJoin Our 70k+ Instagram Community \n\nhttps://instagram.com/errormakesclever?igshid=NTc4MTIwNjQ2YQ==",
#   'Published_Date': '2023-05-08T04:30:12Z',
#   'Duration': 'PT8M48S',
#   'Views': '159834',
#   'Likes': '6846',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'BVIoAILnZ4Q',
#   'Title': '#01 Python Programming Tutorial Series 📚| Introduction to Python 🧑\u200d💻| EMC ACADEMY 💪',
#   'Tags': ['Python',
#    'Python tutorial in tamil',
#    'programming in tamil',
#    'programming playlist',
#    'programming for beginners',
#    'python for beginners in tamil',
#    'python tamil',
#    'learn python in tamil',
#    'programming in 30 days',
#    'python',
#    'Python developer',
#    'you can become a python developer',
#    'how to become a python developer',
#    'how to code',
#    'coding tamil',
#    'brototype coding',
#    'learn coding fully'],
#   'Thumbnail': 'https://i.ytimg.com/vi/BVIoAILnZ4Q/default.jpg',
#   'Description': "Welcome to our Python tutorial series on YouTube! In this series, I will be teaching you Python programming language from scratch in a fun and easy way. Python is a versatile and powerful programming language that is used in a variety of industries, from web development to data science and machine learning. \n\nWhether you're a complete beginner or already have some programming experience, this series is designed to help you learn Python step by step, with clear explanations and practical examples. My goal is to make the learning process enjoyable and accessible, so that you can build a solid foundation in Python and start using it to create your own projects.\n\nSo, get ready to dive into the exciting world of Python with me! We'll cover everything from the basics of Python syntax to advanced topics like object-oriented programming, file handling, and web scraping. By the end of this series, you'll have a thorough understanding of Python and be able to apply your skills to real-world projects. Let's get started!\n\nEverything in Tamil. \n\nJoin our 46K+ Instagram community\n\nhttps://instagram.com/errormakesclever?igshid=NTc4MTIwNjQ2YQ==",
#   'Published_Date': '2023-05-07T03:30:06Z',
#   'Duration': 'PT1M53S',
#   'Views': '241477',
#   'Likes': '10272',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'Y0RoLM48xP4',
#   'Title': 'You can never learn coding if you don’t practice. Start practising coding in these websites. #code',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Y0RoLM48xP4/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-05-04T02:58:09Z',
#   'Duration': 'PT23S',
#   'Views': '765792',
#   'Likes': '84597',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 't_WIjhkZNoA',
#   'Title': 'Should you really take 30k worth course ? #training #trainingcenter',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/t_WIjhkZNoA/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-05-03T02:30:23Z',
#   'Duration': 'PT44S',
#   'Views': '172378',
#   'Likes': '20434',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'jk7q7QTFnvI',
#   'Title': 'How to get google, Microsoft, IBM certificates for free ? . Try this 😉',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/jk7q7QTFnvI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-05-01T12:30:17Z',
#   'Duration': 'PT50S',
#   'Views': '450020',
#   'Likes': '47597',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '5QzzeYHApV0',
#   'Title': 'How to become a full stack developer 🚀 | Web Development Explained | Error Makes Clever Academy',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/5QzzeYHApV0/default.jpg',
#   'Description': 'In this video, I will explain what full stack development is and provide a detailed overview of the technologies used to build full stack web applications. Full stack web development involves building the front-end, back-end, and database components of a web application. This means that full stack developers are responsible for everything from designing the user interface to managing the server-side logic and database.\n\nI will begin by discussing the key technologies and programming languages used in full stack web development, including HTML, CSS, JavaScript, Node.js, and various front-end frameworks such as React and Angular. I will then move on to discuss the server-side technologies like Python, Java and Node Js, and databases like MySQL, MongoDB, and Aws.\n\nThroughout the video, I will provide examples and code snippets to help illustrate how these different technologies are used in practice.\n\nBy the end of this video, you will have a comprehensive understanding of what full stack web development is and the tools and technologies used by full stack developers to create powerful web applications.\n\nEverything explained in detail in Tamil Language.\n\nTechnologies used for full stack development:\n\nFrontEnd \n- HTML\n- CSS\n- JavaScript\n- React\n- Angular\n- Vue\nBackend \n- Express.js\n- Ruby on Rails\n- Python\n- Java\n- Node Js\n- PHP\nDatabases\n- MySQL\n- MongoDB\n- PostgreSQL\n- Aws\n\nJoin our 25k+ Instagram Community\n\nhttps://instagram.com/errormakesclever?igshid=YmMyMTA2M2Y=',
#   'Published_Date': '2023-05-01T04:30:01Z',
#   'Duration': 'PT4M22S',
#   'Views': '172353',
#   'Likes': '11036',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '2baFLrjuW8s',
#   'Title': 'Cloud Computing in 30 seconds. Clear definition about cloud in tamil.',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/2baFLrjuW8s/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-30T04:35:38Z',
#   'Duration': 'PT1M1S',
#   'Views': '343420',
#   'Likes': '34938',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '50F2ysbYLfI',
#   'Title': 'How to move from one company to another ?? Here is a tip for you to switch companies. #jobswitch',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/50F2ysbYLfI/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-27T12:30:05Z',
#   'Duration': 'PT39S',
#   'Views': '36159',
#   'Likes': '4398',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'ZpyJe4_xVVA',
#   'Title': '"Unleashing the Power of Web Development in 30 Seconds! 💻🌐 Exploring HTML, CSS and JS.',
#   'Tags': ['Html',
#    'Css',
#    'JavaScript',
#    'web',
#    'web development',
#    'web development in 30 sec'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ZpyJe4_xVVA/default.jpg',
#   'Description': "In this 30-second video, I give a quick overview of web development, covering the basics of HTML, CSS, and JavaScript, as well as a brief mention of backend development. I explain how HTML provides the structure of a webpage, while CSS is used for styling and design, and JavaScript adds interactivity and dynamic behavior. Additionally, I touch on the importance of backend development in creating a fully functional website, which involves building and managing the server-side code and databases that power web applications. Whether you're a beginner or looking to refresh your knowledge, this video provides a concise introduction to the fundamentals of web development.",
#   'Published_Date': '2023-04-26T12:30:23Z',
#   'Duration': 'PT1M1S',
#   'Views': '218533',
#   'Likes': '30321',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': '7tTB8IaHASc',
#   'Title': 'TCS NQT ALERT ‼️',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/7tTB8IaHASc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-19T12:47:39Z',
#   'Duration': 'PT33S',
#   'Views': '24469',
#   'Likes': '1961',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'ONDDWzXHW28',
#   'Title': 'Interview Tip for freshers!!',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/ONDDWzXHW28/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-19T09:43:53Z',
#   'Duration': 'PT37S',
#   'Views': '122734',
#   'Likes': '16465',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'oBBW3fnGejc',
#   'Title': 'Freshers Try this Hack 💥 #career #careerdevelopment #freshersguide #tips',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/oBBW3fnGejc/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-17T12:45:19Z',
#   'Duration': 'PT35S',
#   'Views': '18706',
#   'Likes': '2281',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'Krzg0YlFHMs',
#   'Title': 'On an average Full Stack developer make 6 - 8LPA. The complete web development bootcamp from @udemy.',
#   'Tags': ['Full stack development', 'Course', 'scam', 'learn'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Krzg0YlFHMs/default.jpg',
#   'Description': 'On an average Full Stack developer make 6 - 8LPA. The complete web development bootcamp from @udemy is everything you need to start your full stack development career.\nCourse Link in Bio!!\n#fullstackdeveloper #webdevelopment #udemy #course',
#   'Published_Date': '2023-04-16T13:48:51Z',
#   'Duration': 'PT36S',
#   'Views': '30787',
#   'Likes': '4099',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'tP8Ku1cjRp4',
#   'Title': 'Use this linkedin Tip in your Job Hunt 💥 #linkedin #careerguide #career #job #errormakesclever',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/tP8Ku1cjRp4/default.jpg',
#   'Description': '',
#   'Published_Date': '2023-04-15T12:30:29Z',
#   'Duration': 'PT36S',
#   'Views': '11148',
#   'Likes': '879',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'Q_mugOseqCc',
#   'Title': 'Here are the top 4 websites to apply for an internship. #career # students #internship #job at',
#   'Tags': ['Career',
#    'Growth',
#    'education',
#    'rich',
#    'money',
#    'motivation',
#    'webdevelopment',
#    'programming',
#    'cloud',
#    'student',
#    'c++',
#    'java',
#    'Ai',
#    'machine learning'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Q_mugOseqCc/default.jpg',
#   'Description': '🤞Here are the top 4 websites to apply for an internship. Only less amount of students consider doing internships, those students are definitely getting placed with higher salary when they graduate. Internships are the best place where you can start your career 📈.\nApply Now !!! \n\n#internship #internshipoffer #student #fresher #placement #career #education #tips #webdevelopment #programming #fullstackdeveloper #cloud #computer #engineer #learning',
#   'Published_Date': '2023-04-14T12:30:24Z',
#   'Duration': 'PT36S',
#   'Views': '212295',
#   'Likes': '29593',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Error Makes Clever Academy',
#   'Channel_Id': 'UCwr-evhuzGZgDFrq_1pLt_A',
#   'Video_Id': 'oubMNuKC8KA',
#   'Title': 'Top 5 Job Search Portal for freshers ! #joboffer #career #job #linkedin',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/oubMNuKC8KA/default.jpg',
#   'Description': 'Here are the top 5 job for search platforms:\n1. Naukri.com - This is one of the oldest and most popular job search platforms in India, with millions of registered job seekers and companies.\n2. Monster India - This platform offers a wide range of job opportunities across various sectors, including IT, finance, marketing, and others.\n3. Indeed - Indeed is a global platform that has a strong presence in India, offering a wide range of largecorporations.\n4. Linkedin - Linkedin is a powerful networking platform that also offers a job search feature, where job seekers can connect with recruiters and employers.\n5. Shine - Shine.com is a leading job search platform in India that offers job\nopportunities across various industries and job roles.\n#success #motivation #inspiration #love #motivationalquotes #life #entrepreneur #mindset #lifestyle #believe #positivevibes #happiness #instagood #instagram #selflove #inspirationalquotes #webdevelopment #webdesign #webdeveloper #html #website #digitalmarketing #coding #programming #javascript #jobsearch #freejob #parttimejob #joboffer',
#   'Published_Date': '2023-04-12T05:52:54Z',
#   'Duration': 'PT44S',
#   'Views': '96005',
#   'Likes': '13767',
#   'Comments': None,
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
#get comment information


def get_comment_info(video_ids):       
    Comment_data=[]                             
    try:                                          
        for video_id in video_ids:                
            request=youtube.commentThreads().list(
                part="snippet",         
                videoId=video_id,
                maxResults=50,
            )
            response=request.execute()

            for item in response['items']:        
                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                        Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                

                Comment_data.append(data)    
                    
    except:
        pass    
    return Comment_data

# %%
comment_details=get_comment_info(Video_Ids)

# %%
len(comment_details)
# Out:
# 5473

# %%
#get_plalist_details


def get_playist_details(channel_id):

        next_page_token=None
        All_data=[]                                      #list created
        while True:
                request=youtube.playlists().list(
                        part='snippet,contentDetails',
                        channelId=channel_id,
                        maxResults=50,
                        pageToken=next_page_token,

                )
                response=request.execute()

                for item in response['items']:
                        data=dict(Playlist_Id=item['id'],
                                Title=item['snippet']['title'],
                                Channel_Id=item['snippet']['channelId'],
                                Channel_Name=item['snippet']['channelTitle'],
                                PublishedAt=item['snippet']['publishedAt'],
                                Video_Count=item['contentDetails']['itemCount'])
                        All_data.append(data)

                next_page_token=response.get("nextpageToken")
                if next_page_token is None:
                        break

        return All_data

# %%
playlist_details=get_playist_details('UCvyZS6W6zMJCZBVzF-Ei6sw')

# %%
playlist_details
# Out:
# [{'Playlist_Id': 'PLN0WDccbRPrp-zHwrN61nQFScHhWCk_OG',
#   'Title': 'Server & Networing - Season 2',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2023-08-01T11:45:29Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PLN0WDccbRPrqAKXLWiCXD2y0Iqv_b87VF',
#   'Title': 'Budget PC Doc',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2023-07-16T05:45:59Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PLN0WDccbRProuFrN88rpyyEezk20ETa0Q',
#   'Title': 'GAMEPLAY KANDHASAMY',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2023-03-19T05:58:44Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PLN0WDccbRPrrDCIAAOx6ixXOQG1VKhcVz',
#   'Title': 'Uruttu Show',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2022-12-27T10:43:44Z',
#   'Video_Count': 0},
#  {'Playlist_Id': 'PLN0WDccbRPrqxMTqy-HqJA2jz7phQ2Zqr',
#   'Title': 'Custom-loop Water Cooling',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2022-11-28T05:12:56Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PLN0WDccbRPrri2odb4n895yMZMqPkhv-V',
#   'Title': 'Server Build',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2022-08-14T11:55:38Z',
#   'Video_Count': 3},
#  {'Playlist_Id': 'PLN0WDccbRPrpiqGOJIzsWVBh-EKU6_vGL',
#   'Title': 'KK Shorts',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2022-06-06T06:16:58Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PLN0WDccbRPrreAKnRZHCBMUQC6mROOx8-',
#   'Title': "PC Doc's Experiments",
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2022-03-15T11:08:48Z',
#   'Video_Count': 13},
#  {'Playlist_Id': 'PLN0WDccbRPrrHmvtTbwj6XKY_40BOBmcM',
#   'Title': 'Crypto Mining',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2021-12-02T08:56:50Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLN0WDccbRPrruq9uZ0lbGT1yAZdYVy9rt',
#   'Title': "PC Doc's Review",
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2021-10-24T04:18:21Z',
#   'Video_Count': 17},
#  {'Playlist_Id': 'PLN0WDccbRPrrKrIFEnh54KKnN1KuJ3jiz',
#   'Title': "KK's Review",
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2021-10-13T10:59:17Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PLN0WDccbRPrqXTvrDpXFx7S0Bk3WkzImd',
#   'Title': 'NETWORKING',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2021-09-05T08:39:53Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PLN0WDccbRProUFMsUm84Xg_HKVhvmi8-3',
#   'Title': 'Cartoon Kandhasamy',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2020-08-23T13:23:15Z',
#   'Video_Count': 11},
#  {'Playlist_Id': 'PLN0WDccbRPrpdrJQ7xOgKITvbjF-vzcXn',
#   'Title': 'A2DBasic',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2020-07-24T06:05:10Z',
#   'Video_Count': 26},
#  {'Playlist_Id': 'PLN0WDccbRPro_V4iFM0pPWx_FMBv0BM5m',
#   'Title': 'Tech உடான்ஸ்',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2020-05-11T06:31:56Z',
#   'Video_Count': 22},
#  {'Playlist_Id': 'PLN0WDccbRProL0NTXnzJx4va2ujsTP8rR',
#   'Title': 'Kalakodu Kandhasami',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2020-04-21T07:27:02Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PLN0WDccbRPrpqQz-v7UyEu7JgSiq03Ex8',
#   'Title': 'Horror Stories',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2020-02-09T05:54:24Z',
#   'Video_Count': 26},
#  {'Playlist_Id': 'PLN0WDccbRProE4yIjvpZDN3bEuddEHPoi',
#   'Title': 'En PC Ku Enna Achi?',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2020-01-23T08:30:34Z',
#   'Video_Count': 21},
#  {'Playlist_Id': 'PLN0WDccbRProoTuGDuH4wvvbkz0TS9Cxc',
#   'Title': 'PC Build TimeLapse',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2019-12-22T10:27:25Z',
#   'Video_Count': 10},
#  {'Playlist_Id': 'PLN0WDccbRPrqXU6JEN4GFeU7a_k45z8EU',
#   'Title': 'Comic KandhaSami',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2019-09-18T12:39:49Z',
#   'Video_Count': 14},
#  {'Playlist_Id': 'PLN0WDccbRProQEXp7K8Ks8e_qAKImE-4i',
#   'Title': 'Kuriyidu KandhaSami',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2019-07-19T03:29:03Z',
#   'Video_Count': 120},
#  {'Playlist_Id': 'PLN0WDccbRProhmGutUf16dwD_Y7zTibOu',
#   'Title': 'GAME STD',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2019-04-07T01:15:43Z',
#   'Video_Count': 19},
#  {'Playlist_Id': 'PLN0WDccbRPrq8HvoFrRipmYwFEYcbT8jc',
#   'Title': 'A News',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2019-02-27T14:02:20Z',
#   'Video_Count': 23},
#  {'Playlist_Id': 'PLN0WDccbRPros34a_HW5CmTiGAjsJcuSl',
#   'Title': 'Endra Shanmugham!!!',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2018-12-30T18:47:59Z',
#   'Video_Count': 47},
#  {'Playlist_Id': 'PLN0WDccbRProTdyA_LCpjVihnhaYLCIVH',
#   'Title': 'VLOG',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2018-09-24T10:41:09Z',
#   'Video_Count': 9},
#  {'Playlist_Id': 'PLN0WDccbRPrqlm-EgSlp4R018hlLBseca',
#   'Title': 'Kadha KandhaSami',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2018-04-23T04:56:14Z',
#   'Video_Count': 80},
#  {'Playlist_Id': 'PLN0WDccbRProwZEZrb8aF7VH9an4wBKeH',
#   'Title': 'Build Ur Own PC',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2018-03-10T19:15:25Z',
#   'Video_Count': 79},
#  {'Playlist_Id': 'PLN0WDccbRProwRX_MY3uJWoDfIbvwRSCV',
#   'Title': 'Kelu Mavaney Kelu',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2018-02-25T14:02:51Z',
#   'Video_Count': 3},
#  {'Playlist_Id': 'PLN0WDccbRPrroZSNgfBwepOIQAFLXSw0F',
#   'Title': '10 kulla number onnu sollu',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2018-02-18T12:31:30Z',
#   'Video_Count': 10},
#  {'Playlist_Id': 'PLN0WDccbRPrr7eE46ZSZbqrfnWsjK68yE',
#   'Title': 'MNP',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2017-08-25T04:01:24Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PLN0WDccbRPrqaIc1zJLIIEDnGuVgCNsCJ',
#   'Title': 'Watha Gaming',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2017-05-10T07:44:07Z',
#   'Video_Count': 3},
#  {'Playlist_Id': 'PLN0WDccbRPrrOXKqwDt9PLmWeJP8NCz9G',
#   'Title': 'Akku Veru Aani Veru',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2017-05-10T07:43:16Z',
#   'Video_Count': 36},
#  {'Playlist_Id': 'PLN0WDccbRPrrx0VKO_EXjIM9d2QV25_-K',
#   'Title': 'A2D Reviews',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Channel_Name': 'A2D Channel',
#   'PublishedAt': '2016-10-11T08:59:12Z',
#   'Video_Count': 11}]

# %%
#upload to mongodb

client=pymongo.MongoClient("mongodb+srv://hiruthickpitchai:hiruthickmongo@cluster0.vhgpwq5.mongodb.net/?retryWrites=true&w=majority")
db=client["youtube_data"]

# %%
#error makes clever academy  :    UCwr-evhuzGZgDFrq_1pLt_A
#hrnavin  : UC-O3_F-UpwzKvSkvO0DW9qg
#a2d     :  UCvyZS6W6zMJCZBVzF-Ei6sw
#gowtham : UCtzTaAQI_pnOKJ8PQmVDxSw

# %%
def channel_details(channel_id):
    ch_details=get_Channel_info(channel_id)
    pl_details=get_playist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)


    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                      "video_information":vi_details,"comment_information":com_details})
    
    return "upload completed sucessfully"

# %%
#table creation for channel,playlist,videos,comments

def channels_table():

    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="postgres",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()


    drop_query='''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                        Channel_Id varchar(80) primary key,
                                                        Subscription_Count bigint,
                                                        Views bigint,
                                                        Total_Videos int,
                                                        Channel_Description text,
                                                        Playlist_Id varchar(80))'''
        cursor.execute(create_query)
        mydb.commit()

    except :
        print("Channels table already created")

    #get data from mongo db
        
    ch_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=pd.DataFrame(ch_list)




    for index,row in df.iterrows():
        insert_query='''insert into channels(Channel_Name ,
                                            Channel_Id,
                                            Subscription_Count,
                                            Views,
                                            Total_Videos,
                                            Channel_Description,
                                            Playlist_Id)
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        
        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Subscription_Count'],
                row['Views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row['Playlist_Id'])
        

        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("channels values are already inserted")

# %%
def playlist_table():

    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="postgres",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()


    drop_query='''drop table if exists playlists'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query='''create table if not exists playlists(Playlist_Id varchar(100)primary key,
                                                    Title varchar(100),
                                                    Channel_Id varchar(100),
                                                    Channel_Name varchar(100),
                                                    PublishedAt timestamp,
                                                    Video_Count int
                                                    )'''
        



    cursor.execute(create_query)
    mydb.commit()


    pl_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
    df1=pd.DataFrame(pl_list)


    for index,row in df1.iterrows():
        insert_query='''insert into playlists(Playlist_Id,
                                            Title,
                                            Channel_Id,
                                            Channel_Name,
                                            PublishedAt,
                                            Video_Count)

                                             
                                            
                                            values(%s,%s,%s,%s,%s,%s)'''
       
        
        values=(row['Playlist_Id'],
                row['Title'],
                row['Channel_Id'],
                row['Channel_Name'],
                row['PublishedAt'],
                row['Video_Count']
                )
        

        
        cursor.execute(insert_query,values)
    mydb.commit()

# %%
def videos_table():


    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="postgres",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()


    drop_query='''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query='''create table if not exists videos(Channel_Name varchar(100),
                                                    Channel_Id varchar(100),
                                                    Video_Id varchar(30)primary key,
                                                    Title varchar(150),
                                                    Tags text,
                                                    Thumbnail varchar(200),
                                                    Description text,
                                                    Published_Date timestamp,
                                                    Duration interval,
                                                    Views bigint,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favorite_Count int,
                                                    Definition varchar(10),
                                                    Caption_Status varchar(50)
                                                    )'''
        



    cursor.execute(create_query)
    mydb.commit()


    vi_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    df2=pd.DataFrame(vi_list)




    for index,row in df2.iterrows():
            insert_query='''insert into videos(Channel_Name,
                                                    Channel_Id,
                                                    Video_Id,
                                                    Title,
                                                    Tags,
                                                    Thumbnail,
                                                    Description,
                                                    Published_Date,
                                                    Duration,
                                                    Views,
                                                    Likes,
                                                    Comments,
                                                    Favorite_Count,
                                                    Definition,
                                                    Caption_Status)
        

                                                
                                                
                                                values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
            
        
            
            values=(row['Channel_Name'],
                    row['Channel_Id'],
                    row['Video_Id'],
                    row['Title'],
                    row['Tags'],
                    row['Thumbnail'],
                    row['Description'],
                    row['Published_Date'],
                    row['Duration'],
                    row['Views'],
                    row['Likes'],
                    row['Comments'],
                    row['Favorite_Count'],
                    row['Definition'],
                    row['Caption_Status']
                    )
            

            
    cursor.execute(insert_query,values)
    mydb.commit()

# %%
def comments_table():

    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="postgres",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()


    drop_query='''drop table if exists comments'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query='''create table if not exists comments(Comment_Id varchar(100) primary key,
                                                        Video_Id varchar(50),
                                                        Comment_Text text,
                                                        Comment_Author varchar(150),
                                                        Comment_Published timestamp
                                                    )'''
        



    cursor.execute(create_query)
    mydb.commit()

    com_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
    df3=pd.DataFrame(com_list)



    for index,row in df3.iterrows():
            insert_query='''insert into comments(Comment_Id,
                                                    Video_Id,
                                                    Comment_Text,
                                                    Comment_Author,
                                                    Comment_Published
                                                    )

                                                
                                                
                                                values(%s,%s,%s,%s,%s)'''
        
            
            values=(row['Comment_Id'],
                    row['Video_Id'],
                    row['Comment_Text'],
                    row['Comment_Author'],
                    row['Comment_Published']
                    )
            

            
            cursor.execute(insert_query,values)
            mydb.commit()

# %%
def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_table()

    return "Tables Created Successfully"

# %%
Tables=tables()

# %%
Tables
# Out:
# 'Tables Created Successfully'

# %%
def show_channels_table():
    ch_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=st.dataframe(ch_list)

    return df

# %%
def show_playlists_table():
    pl_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
    df1=st.dataframe(pl_list)

    return df1

# %%
def show_videos_table():
    vi_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    df2=st.dataframe(vi_list)

    return df2

# %%
def show_comments_table():
    com_list=[]
    db=client["youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
    df3=st.dataframe(com_list)

    return df3

# %%
#streamlit part

with st.sidebar:
    st.title(":red[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("SKILL TAKE AWAY")
    st.caption("Python scrippting")
    st.caption("Data Collection")
    st.caption("MongoDB")
    st.caption("API Integration")
    st.caption("Data Management using MongoDB and SQL")



channel_id=st.text_input("Enter the channel ID")

if st.button("collect and store data"):
    ch_ids=[]
    db=client["Youtube_data"]
    coll1=db["channnel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data)["channel_information"]["Channel_Id"]

    if channel_id in ch_ids:
        st.success("Channels details of the given channel id already exists") 

    else:
        insert=channel_details(channel_id)
        st.success(insert)   

if st.button("Migrate to sql"):
    Table=tables()
    st.success(Table)

show_table=st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))

if show_table=="CHANNELS":
    show_channels_table()

elif show_table=="PLAYLISTS":
    show_playlists_table

elif show_table=="VIDEOS":
    show_videos_table()    

elif show_table=="COMMENTS":
    show_comments_table()
# Out:
# 2024-02-10 14:05:05.160
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\New folder\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
#sql connection

mydb=psycopg2.connect(host="localhost",
                    user="postgres",
                    password="postgres",
                    database="youtube_data",
                    port="5432")
cursor=mydb.cursor()

question=st.selectbox("select your question",("1. All the videos in the channel name",
                                              "2. channels with most viewed videos",
                                              "3. 10 most viewed videos",
                                              "4. comments in each videos",
                                              "5. videos with highest likes"
                                              "6. likes of all videos",
                                              "7. views of each channel",
                                              "8. videos published in the year of 2022",
                                              "9. average duration of all videos in each channnel",
                                              "10. videos with the highest number of comments"))


if question=="1. All the videos in the channel name":
    query1='''select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["video title","channel name"])
    st.dataframe(df)

elif question=="2. channels with most viewed videos":
    query2='''select channel_name as channelname,total_videos as no_videos from channels
                order by total_videos desc'''
    cursor.execute(query2)
    mydb.commit
    t2=cursor.fetchall()
    df2=pd.DataFrame(t2,columns=["channel name","no of videos"])
    st.dataframe(df2)

elif question=="3. 10 most viewed videos":
    query3='''select views as views ,channel_name as channelname,title as videotitle from videos
            where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit
    t3=cursor.fetchall()
    df3=pd.DataFrame(t3,columns=["views","channel name","videotitle"])
    st.dataframe(df3)

elif question=="4.comments in each videos":
    query4='''select comments as no_comments ,title as videotitle from videos where comments is not null'''
    cursor.execute(query4)
    mydb.commit
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=["no of comments","videotitle"])
    st.dataframe(df4)

elif question=="5. videos with highest likes":
    query5='''select title as videotitle,channel_name as channelname,likes as likescount
                from videos where likes is not null order by likes desc'''
    cursor.execute(query5)
    mydb.commit
    t5=cursor.fetchall()
    df5=pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
    st.dataframe(df5)
    
elif question=="6. likes of all videos":
    query6='''select likes as likecount,title as videotitle from videos'''
    cursor.execute(query6)
    mydb.commit
    t6=cursor.fetchall()
    df6=pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
    st.dataframe(df6)   

elif question=="7. views of each channel":
    query7='''select channel_name as channelname,views as totslviews from channels '''
    cursor.execute(query7)
    mydb.commit
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7,columns=["channel name","totalviews"])
    st.dataframe(df7)

elif question=="8. videos published in the year of 2022":
    query8='''select title as video_title,published_date as videorelease,channel_name as channelname from videos
                where extract(year from published_date)=2022'''
    cursor.execute(query8)
    mydb.commit
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["videotitle","published_date","totalviews","channelname"])
    st.dataframe(df8)

elif question=="9. average duration of all videos in each channnel":
    query9='''select channel_name as channelname,AVG(duration) as averageduration from videos group by channel_name'''
    cursor.execute(query9)
    mydb.commit
    t9=cursor.fetchall()
    df9=pd.DataFrame(t9,columns=["channelname","averageduration"])

    T9=[]
    for index,row in df9.iterrows():
        channel_title=row["channelname"]
        average_duration=row["averageduration"]
        average_duration_str=str(average_duration)
        T9.append(dict(channeltitle=channel_title,avgduration=average_duration_str))
    df1=pd.DataFrame(T9)
    st.dataframe(df1)

elif question=="10. videos with the highest number of comments":
    query10='''select title as videotitle,channel_name as channelname,comments as comments from videos where comments is 
                not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10,columns=["video title","channelname","comments"])
    st.dataframe(df10)

# %%
mydb=psycopg2.connect(host="localhost",
                    user="postgres",
                    password="postgres",
                    database="youtube_data",
                    port="5432")
cursor=mydb.cursor()
#elif question=="10. videos with the highest number of comments":
query10='''select title as videotitle,channel_name as channelname,comments as comments from videos where comments is 
            not null order by comments desc'''
cursor.execute(query10)
mydb.commit
t10=cursor.fetchall()
df10=pd.DataFrame(t10,columns=["video title","channelname","comments"])
df10
# Out:
# Empty DataFrame
# Columns: [video title, channelname, comments]
# Index: []

# %%
T9
# Out:
# [{'channeltitle': "Nivi's Junction", 'avgduration': '0 days 00:01:15'}]

# %%
df1
# Out:
#       channeltitle      avgduration
# 0  Nivi's Junction  0 days 00:01:15
